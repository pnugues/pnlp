# %% [markdown]
# # Chapter 13: Subword Segmentation
# ## Subword Tokenizers: WordPiece
# Tokenizers using WordPiece (Schuster and Nakajima, 2012): https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=6289079

# %% [markdown]
# Programs from the book: [_Python for Natural Language Processing_](https://link.springer.com/book/9783031575488)
#
# __Author__: Pierre Nugues

# %%
import os
import regex as re
from collections import Counter
from math import log

# %% [markdown]
# ## Corpus Files

# %% [markdown]
# We read the files and we store the corpus in a string

# %%
PATH = '../datasets/'

# %%
CORPUS = 'HOMER'  # 'DICKENS'

# %%
if CORPUS == 'DICKENS':
    folder = PATH + 'dickens/'
elif CORPUS == 'HOMER':
    folder = PATH + 'classics/'

# %%
def get_files(dir, suffix):
    """
    Returns all the files in a folder ending with suffix
    :param dir:
    :param suffix:
    :return: the list of file names
    """
    files = []
    for file in os.listdir(dir):
        if file.endswith(suffix):
            files.append(file)
    return files

# %%
if CORPUS == 'DICKENS':
    files = get_files(folder, 'txt')
elif CORPUS == 'HOMER':
    files = ['iliad.txt', 'odyssey.txt']
files
# Out:
# ['iliad.txt', 'odyssey.txt']

# %%
files = [folder + file for file in files]
files
# Out:
# ['../datasets/classics/iliad.txt', '../datasets/classics/odyssey.txt']

# %%
text = ''
for file in files:
    with open(file, encoding='utf8') as f:
        text += ' ' + f.read().strip()

# %%
text[:100]
# Out:
# ' BOOK I\n\nSing, O goddess, the anger of Achilles son of Peleus, that brought\ncountless ills upon the '

# %% [markdown]
# ## Pretokenization

# %% [markdown]
# We pretokenize the text using the spaces as delimiters.
# In BERT, simply `split()`: https://github.com/google-research/bert/blob/master/tokenization.py#L300-L359. Here we use a regex.

# %%
pattern = r'\p{P}|[^\s\p{P}]+'

# %%
words = [(match.group(), (match.start(), match.end()))
         for match in re.finditer(pattern, text)]

# %%
text.split()[:8]
# Out:
# ['BOOK', 'I', 'Sing,', 'O', 'goddess,', 'the', 'anger', 'of']

# %%
words[:8]
# Out:
# [('BOOK', (1, 5)),
#  ('I', (6, 7)),
#  ('Sing', (9, 13)),
#  (',', (13, 14)),
#  ('O', (15, 16)),
#  ('goddess', (17, 24)),
#  (',', (24, 25)),
#  ('the', (26, 29))]

# %%
def pretokenize(pattern, text):
    return re.findall(pattern, text)

# %%
words = pretokenize(pattern, text)

# %%
word_cnts = Counter(words)

# %%
word_cnts.most_common(5)
# Out:
# [(',', 19920), ('the', 15258), ('and', 11467), ('of', 8640), ('.', 8108)]

# %%
word_cnts['her']
# Out:
# 1145

# %% [markdown]
# ## The Class
# Same as with BPE. We create a second dictionary to count the subword tokens. At each iteration, the keys will store the subtokens. We set a ▁ symbol (U+2581) to mark the start of a word.

# %%
class WordPiece():
    def __init__(self, merge_cnt=200):
        self.pattern = r'\p{P}|[^\s\p{P}]+'
        self.merge_cnt = merge_cnt

    def pretokenize(self, text):
        words = re.findall(self.pattern, text)
        words = list(map(lambda x: '▁' + x, words))
        return words

    def _wp_init(self, text):
        words = self.pretokenize(text)
        word_cnts = Counter(words)
        self.words_wp = {
            word: {'freq': freq, 'swords': list(word)}
            for word, freq in word_cnts.items()}
        self.vocab = list(
            set([char for word in self.words_wp
                 for char in self.words_wp[word]['swords']]))

# %%
wp = WordPiece()
wp._wp_init(text)

# %%
wp.words_wp
# Out:
# {'▁BOOK': {'freq': 48, 'swords': ['▁', 'B', 'O', 'O', 'K']},
#  '▁I': {'freq': 3194, 'swords': ['▁', 'I']},
#  '▁Sing': {'freq': 2, 'swords': ['▁', 'S', 'i', 'n', 'g']},
#  '▁,': {'freq': 19920, 'swords': ['▁', ',']},
#  '▁O': {'freq': 77, 'swords': ['▁', 'O']},
#  '▁goddess': {'freq': 112, 'swords': ['▁', 'g', 'o', 'd', 'd', 'e', 's', 's']},
#  '▁the': {'freq': 15258, 'swords': ['▁', 't', 'h', 'e']},
#  '▁anger': {'freq': 74, 'swords': ['▁', 'a', 'n', 'g', 'e', 'r']},
#  '▁of': {'freq': 8640, 'swords': ['▁', 'o', 'f']},
#  '▁Achilles': {'freq': 440,
#   'swords': ['▁', 'A', 'c', 'h', 'i', 'l', 'l', 'e', 's']},
#  '▁son': {'freq': 1246, 'swords': ['▁', 's', 'o', 'n']},
#  '▁Peleus': {'freq': 145, 'swords': ['▁', 'P', 'e', 'l', 'e', 'u', 's']},
#  '▁that': {'freq': 2558, 'swords': ['▁', 't', 'h', 'a', 't']},
#  '▁brought': {'freq': 208, 'swords': ['▁', 'b', 'r', 'o', 'u', 'g', 'h', 't']},
#  '▁countless': {'freq': 8,
#   'swords': ['▁', 'c', 'o', 'u', 'n', 't', 'l', 'e', 's', 's']},
#  '▁ills': {'freq': 5, 'swords': ['▁', 'i', 'l', 'l', 's']},
#  '▁upon': {'freq': 792, 'swords': ['▁', 'u', 'p', 'o', 'n']},
#  '▁Achaeans': {'freq': 601,
#   'swords': ['▁', 'A', 'c', 'h', 'a', 'e', 'a', 'n', 's']},
#  '▁.': {'freq': 8108, 'swords': ['▁', '.']},
#  '▁Many': {'freq': 26, 'swords': ['▁', 'M', 'a', 'n', 'y']},
#  '▁a': {'freq': 3575, 'swords': ['▁', 'a']},
#  '▁brave': {'freq': 157, 'swords': ['▁', 'b', 'r', 'a', 'v', 'e']},
#  '▁soul': {'freq': 30, 'swords': ['▁', 's', 'o', 'u', 'l']},
#  '▁did': {'freq': 748, 'swords': ['▁', 'd', 'i', 'd']},
#  '▁it': {'freq': 2109, 'swords': ['▁', 'i', 't']},
#  '▁send': {'freq': 103, 'swords': ['▁', 's', 'e', 'n', 'd']},
#  '▁hurrying': {'freq': 10,
#   'swords': ['▁', 'h', 'u', 'r', 'r', 'y', 'i', 'n', 'g']},
#  '▁down': {'freq': 454, 'swords': ['▁', 'd', 'o', 'w', 'n']},
#  '▁to': {'freq': 6492, 'swords': ['▁', 't', 'o']},
#  '▁Hades': {'freq': 77, 'swords': ['▁', 'H', 'a', 'd', 'e', 's']},
#  '▁and': {'freq': 11467, 'swords': ['▁', 'a', 'n', 'd']},
#  '▁many': {'freq': 310, 'swords': ['▁', 'm', 'a', 'n', 'y']},
#  '▁hero': {'freq': 53, 'swords': ['▁', 'h', 'e', 'r', 'o']},
#  '▁yield': {'freq': 18, 'swords': ['▁', 'y', 'i', 'e', 'l', 'd']},
#  '▁prey': {'freq': 11, 'swords': ['▁', 'p', 'r', 'e', 'y']},
#  '▁dogs': {'freq': 56, 'swords': ['▁', 'd', 'o', 'g', 's']},
#  '▁vultures': {'freq': 21,
#   'swords': ['▁', 'v', 'u', 'l', 't', 'u', 'r', 'e', 's']},
#  '▁for': {'freq': 2653, 'swords': ['▁', 'f', 'o', 'r']},
#  '▁so': {'freq': 1316, 'swords': ['▁', 's', 'o']},
#  '▁were': {'freq': 1151, 'swords': ['▁', 'w', 'e', 'r', 'e']},
#  '▁counsels': {'freq': 22,
#   'swords': ['▁', 'c', 'o', 'u', 'n', 's', 'e', 'l', 's']},
#  '▁Jove': {'freq': 653, 'swords': ['▁', 'J', 'o', 'v', 'e']},
#  '▁fulfilled': {'freq': 9,
#   'swords': ['▁', 'f', 'u', 'l', 'f', 'i', 'l', 'l', 'e', 'd']},
#  '▁from': {'freq': 1522, 'swords': ['▁', 'f', 'r', 'o', 'm']},
#  '▁day': {'freq': 242, 'swords': ['▁', 'd', 'a', 'y']},
#  '▁on': {'freq': 1811, 'swords': ['▁', 'o', 'n']},
#  '▁which': {'freq': 669, 'swords': ['▁', 'w', 'h', 'i', 'c', 'h']},
#  '▁Atreus': {'freq': 151, 'swords': ['▁', 'A', 't', 'r', 'e', 'u', 's']},
#  '▁king': {'freq': 129, 'swords': ['▁', 'k', 'i', 'n', 'g']},
#  '▁men': {'freq': 689, 'swords': ['▁', 'm', 'e', 'n']},
#  '▁great': {'freq': 459, 'swords': ['▁', 'g', 'r', 'e', 'a', 't']},
#  '▁first': {'freq': 230, 'swords': ['▁', 'f', 'i', 'r', 's', 't']},
#  '▁fell': {'freq': 252, 'swords': ['▁', 'f', 'e', 'l', 'l']},
#  '▁out': {'freq': 689, 'swords': ['▁', 'o', 'u', 't']},
#  '▁with': {'freq': 2710, 'swords': ['▁', 'w', 'i', 't', 'h']},
#  '▁one': {'freq': 975, 'swords': ['▁', 'o', 'n', 'e']},
#  '▁another': {'freq': 282, 'swords': ['▁', 'a', 'n', 'o', 't', 'h', 'e', 'r']},
#  '▁And': {'freq': 195, 'swords': ['▁', 'A', 'n', 'd']},
#  '▁gods': {'freq': 417, 'swords': ['▁', 'g', 'o', 'd', 's']},
#  '▁was': {'freq': 2158, 'swords': ['▁', 'w', 'a', 's']},
#  '▁set': {'freq': 330, 'swords': ['▁', 's', 'e', 't']},
#  '▁them': {'freq': 1811, 'swords': ['▁', 't', 'h', 'e', 'm']},
#  '▁quarrel': {'freq': 26, 'swords': ['▁', 'q', 'u', 'a', 'r', 'r', 'e', 'l']},
#  '▁?': {'freq': 570, 'swords': ['▁', '?']},
#  '▁It': {'freq': 159, 'swords': ['▁', 'I', 't']},
#  '▁Leto': {'freq': 15, 'swords': ['▁', 'L', 'e', 't', 'o']},
#  '▁;': {'freq': 2510, 'swords': ['▁', ';']},
#  '▁he': {'freq': 4189, 'swords': ['▁', 'h', 'e']},
#  '▁angry': {'freq': 114, 'swords': ['▁', 'a', 'n', 'g', 'r', 'y']},
#  '▁sent': {'freq': 176, 'swords': ['▁', 's', 'e', 'n', 't']},
#  '▁pestilence': {'freq': 5,
#   'swords': ['▁', 'p', 'e', 's', 't', 'i', 'l', 'e', 'n', 'c', 'e']},
#  '▁host': {'freq': 114, 'swords': ['▁', 'h', 'o', 's', 't']},
#  '▁plague': {'freq': 6, 'swords': ['▁', 'p', 'l', 'a', 'g', 'u', 'e']},
#  '▁people': {'freq': 340, 'swords': ['▁', 'p', 'e', 'o', 'p', 'l', 'e']},
#  '▁because': {'freq': 71, 'swords': ['▁', 'b', 'e', 'c', 'a', 'u', 's', 'e']},
#  '▁had': {'freq': 1725, 'swords': ['▁', 'h', 'a', 'd']},
#  '▁dishonoured': {'freq': 6,
#   'swords': ['▁', 'd', 'i', 's', 'h', 'o', 'n', 'o', 'u', 'r', 'e', 'd']},
#  '▁Chryses': {'freq': 7, 'swords': ['▁', 'C', 'h', 'r', 'y', 's', 'e', 's']},
#  '▁his': {'freq': 3749, 'swords': ['▁', 'h', 'i', 's']},
#  '▁priest': {'freq': 14, 'swords': ['▁', 'p', 'r', 'i', 'e', 's', 't']},
#  '▁Now': {'freq': 122, 'swords': ['▁', 'N', 'o', 'w']},
#  '▁come': {'freq': 518, 'swords': ['▁', 'c', 'o', 'm', 'e']},
#  '▁ships': {'freq': 519, 'swords': ['▁', 's', 'h', 'i', 'p', 's']},
#  '▁free': {'freq': 30, 'swords': ['▁', 'f', 'r', 'e', 'e']},
#  '▁daughter': {'freq': 165,
#   'swords': ['▁', 'd', 'a', 'u', 'g', 'h', 't', 'e', 'r']},
#  '▁him': {'freq': 2926, 'swords': ['▁', 'h', 'i', 'm']},
#  '▁ransom': {'freq': 38, 'swords': ['▁', 'r', 'a', 'n', 's', 'o', 'm']},
#  '▁:': {'freq': 254, 'swords': ['▁', ':']},
#  '▁moreover': {'freq': 59,
#   'swords': ['▁', 'm', 'o', 'r', 'e', 'o', 'v', 'e', 'r']},
#  '▁bore': {'freq': 92, 'swords': ['▁', 'b', 'o', 'r', 'e']},
#  '▁in': {'freq': 3791, 'swords': ['▁', 'i', 'n']},
#  '▁hand': {'freq': 378, 'swords': ['▁', 'h', 'a', 'n', 'd']},
#  '▁sceptre': {'freq': 21, 'swords': ['▁', 's', 'c', 'e', 'p', 't', 'r', 'e']},
#  '▁Apollo': {'freq': 170, 'swords': ['▁', 'A', 'p', 'o', 'l', 'l', 'o']},
#  '▁wreathed': {'freq': 3,
#   'swords': ['▁', 'w', 'r', 'e', 'a', 't', 'h', 'e', 'd']},
#  '▁suppliant': {'freq': 16,
#   'swords': ['▁', 's', 'u', 'p', 'p', 'l', 'i', 'a', 'n', 't']},
#  "▁'": {'freq': 1145, 'swords': ['▁', "'"]},
#  '▁s': {'freq': 616, 'swords': ['▁', 's']},
#  '▁wreath': {'freq': 3, 'swords': ['▁', 'w', 'r', 'e', 'a', 't', 'h']},
#  '▁besought': {'freq': 20,
#   'swords': ['▁', 'b', 'e', 's', 'o', 'u', 'g', 'h', 't']},
#  '▁but': {'freq': 1601, 'swords': ['▁', 'b', 'u', 't']},
#  '▁most': {'freq': 137, 'swords': ['▁', 'm', 'o', 's', 't']},
#  '▁all': {'freq': 1601, 'swords': ['▁', 'a', 'l', 'l']},
#  '▁two': {'freq': 400, 'swords': ['▁', 't', 'w', 'o']},
#  '▁sons': {'freq': 196, 'swords': ['▁', 's', 'o', 'n', 's']},
#  '▁who': {'freq': 1247, 'swords': ['▁', 'w', 'h', 'o']},
#  '▁their': {'freq': 1328, 'swords': ['▁', 't', 'h', 'e', 'i', 'r']},
#  '▁chiefs': {'freq': 20, 'swords': ['▁', 'c', 'h', 'i', 'e', 'f', 's']},
#  '▁"': {'freq': 3574, 'swords': ['▁', '"']},
#  '▁Sons': {'freq': 4, 'swords': ['▁', 'S', 'o', 'n', 's']},
#  '▁cried': {'freq': 100, 'swords': ['▁', 'c', 'r', 'i', 'e', 'd']},
#  '▁other': {'freq': 443, 'swords': ['▁', 'o', 't', 'h', 'e', 'r']},
#  '▁may': {'freq': 533, 'swords': ['▁', 'm', 'a', 'y']},
#  '▁dwell': {'freq': 35, 'swords': ['▁', 'd', 'w', 'e', 'l', 'l']},
#  '▁Olympus': {'freq': 99, 'swords': ['▁', 'O', 'l', 'y', 'm', 'p', 'u', 's']},
#  '▁grant': {'freq': 45, 'swords': ['▁', 'g', 'r', 'a', 'n', 't']},
#  '▁you': {'freq': 3521, 'swords': ['▁', 'y', 'o', 'u']},
#  '▁sack': {'freq': 27, 'swords': ['▁', 's', 'a', 'c', 'k']},
#  '▁city': {'freq': 291, 'swords': ['▁', 'c', 'i', 't', 'y']},
#  '▁Priam': {'freq': 192, 'swords': ['▁', 'P', 'r', 'i', 'a', 'm']},
#  '▁reach': {'freq': 64, 'swords': ['▁', 'r', 'e', 'a', 'c', 'h']},
#  '▁your': {'freq': 1210, 'swords': ['▁', 'y', 'o', 'u', 'r']},
#  '▁homes': {'freq': 7, 'swords': ['▁', 'h', 'o', 'm', 'e', 's']},
#  '▁safety': {'freq': 11, 'swords': ['▁', 's', 'a', 'f', 'e', 't', 'y']},
#  '▁my': {'freq': 1393, 'swords': ['▁', 'm', 'y']},
#  '▁accept': {'freq': 15, 'swords': ['▁', 'a', 'c', 'c', 'e', 'p', 't']},
#  '▁her': {'freq': 1145, 'swords': ['▁', 'h', 'e', 'r']},
#  '▁reverence': {'freq': 3,
#   'swords': ['▁', 'r', 'e', 'v', 'e', 'r', 'e', 'n', 'c', 'e']},
#  '▁On': {'freq': 130, 'swords': ['▁', 'O', 'n']},
#  '▁this': {'freq': 942, 'swords': ['▁', 't', 'h', 'i', 's']},
#  '▁rest': {'freq': 89, 'swords': ['▁', 'r', 'e', 's', 't']},
#  '▁voice': {'freq': 67, 'swords': ['▁', 'v', 'o', 'i', 'c', 'e']},
#  '▁respecting': {'freq': 2,
#   'swords': ['▁', 'r', 'e', 's', 'p', 'e', 'c', 't', 'i', 'n', 'g']},
#  '▁taking': {'freq': 60, 'swords': ['▁', 't', 'a', 'k', 'i', 'n', 'g']},
#  '▁offered': {'freq': 52, 'swords': ['▁', 'o', 'f', 'f', 'e', 'r', 'e', 'd']},
#  '▁not': {'freq': 1572, 'swords': ['▁', 'n', 'o', 't']},
#  '▁Agamemnon': {'freq': 231,
#   'swords': ['▁', 'A', 'g', 'a', 'm', 'e', 'm', 'n', 'o', 'n']},
#  '▁spoke': {'freq': 254, 'swords': ['▁', 's', 'p', 'o', 'k', 'e']},
#  '▁fiercely': {'freq': 31,
#   'swords': ['▁', 'f', 'i', 'e', 'r', 'c', 'e', 'l', 'y']},
#  '▁roughly': {'freq': 4, 'swords': ['▁', 'r', 'o', 'u', 'g', 'h', 'l', 'y']},
#  '▁away': {'freq': 270, 'swords': ['▁', 'a', 'w', 'a', 'y']},
#  '▁Old': {'freq': 13, 'swords': ['▁', 'O', 'l', 'd']},
#  '▁man': {'freq': 769, 'swords': ['▁', 'm', 'a', 'n']},
#  '▁said': {'freq': 888, 'swords': ['▁', 's', 'a', 'i', 'd']},
#  '▁let': {'freq': 441, 'swords': ['▁', 'l', 'e', 't']},
#  '▁me': {'freq': 1620, 'swords': ['▁', 'm', 'e']},
#  '▁find': {'freq': 149, 'swords': ['▁', 'f', 'i', 'n', 'd']},
#  '▁tarrying': {'freq': 2,
#   'swords': ['▁', 't', 'a', 'r', 'r', 'y', 'i', 'n', 'g']},
#  '▁about': {'freq': 706, 'swords': ['▁', 'a', 'b', 'o', 'u', 't']},
#  '▁our': {'freq': 431, 'swords': ['▁', 'o', 'u', 'r']},
#  '▁nor': {'freq': 342, 'swords': ['▁', 'n', 'o', 'r']},
#  '▁yet': {'freq': 257, 'swords': ['▁', 'y', 'e', 't']},
#  '▁coming': {'freq': 105, 'swords': ['▁', 'c', 'o', 'm', 'i', 'n', 'g']},
#  '▁hereafter': {'freq': 34,
#   'swords': ['▁', 'h', 'e', 'r', 'e', 'a', 'f', 't', 'e', 'r']},
#  '▁Your': {'freq': 24, 'swords': ['▁', 'Y', 'o', 'u', 'r']},
#  '▁god': {'freq': 211, 'swords': ['▁', 'g', 'o', 'd']},
#  '▁shall': {'freq': 564, 'swords': ['▁', 's', 'h', 'a', 'l', 'l']},
#  '▁profit': {'freq': 3, 'swords': ['▁', 'p', 'r', 'o', 'f', 'i', 't']},
#  '▁nothing': {'freq': 153, 'swords': ['▁', 'n', 'o', 't', 'h', 'i', 'n', 'g']},
#  '▁will': {'freq': 1496, 'swords': ['▁', 'w', 'i', 'l', 'l']},
#  '▁She': {'freq': 140, 'swords': ['▁', 'S', 'h', 'e']},
#  '▁grow': {'freq': 22, 'swords': ['▁', 'g', 'r', 'o', 'w']},
#  '▁old': {'freq': 249, 'swords': ['▁', 'o', 'l', 'd']},
#  '▁house': {'freq': 539, 'swords': ['▁', 'h', 'o', 'u', 's', 'e']},
#  '▁at': {'freq': 1168, 'swords': ['▁', 'a', 't']},
#  '▁Argos': {'freq': 50, 'swords': ['▁', 'A', 'r', 'g', 'o', 's']},
#  '▁far': {'freq': 194, 'swords': ['▁', 'f', 'a', 'r']},
#  '▁own': {'freq': 544, 'swords': ['▁', 'o', 'w', 'n']},
#  '▁home': {'freq': 316, 'swords': ['▁', 'h', 'o', 'm', 'e']},
#  '▁busying': {'freq': 1, 'swords': ['▁', 'b', 'u', 's', 'y', 'i', 'n', 'g']},
#  '▁herself': {'freq': 57, 'swords': ['▁', 'h', 'e', 'r', 's', 'e', 'l', 'f']},
#  '▁loom': {'freq': 12, 'swords': ['▁', 'l', 'o', 'o', 'm']},
#  '▁visiting': {'freq': 2,
#   'swords': ['▁', 'v', 'i', 's', 'i', 't', 'i', 'n', 'g']},
#  '▁couch': {'freq': 19, 'swords': ['▁', 'c', 'o', 'u', 'c', 'h']},
#  '▁go': {'freq': 514, 'swords': ['▁', 'g', 'o']},
#  '▁do': {'freq': 630, 'swords': ['▁', 'd', 'o']},
#  '▁provoke': {'freq': 6, 'swords': ['▁', 'p', 'r', 'o', 'v', 'o', 'k', 'e']},
#  '▁or': {'freq': 759, 'swords': ['▁', 'o', 'r']},
#  '▁be': {'freq': 1096, 'swords': ['▁', 'b', 'e']},
#  '▁worse': {'freq': 31, 'swords': ['▁', 'w', 'o', 'r', 's', 'e']},
#  '▁The': {'freq': 534, 'swords': ['▁', 'T', 'h', 'e']},
#  '▁feared': {'freq': 19, 'swords': ['▁', 'f', 'e', 'a', 'r', 'e', 'd']},
#  '▁obeyed': {'freq': 15, 'swords': ['▁', 'o', 'b', 'e', 'y', 'e', 'd']},
#  '▁Not': {'freq': 14, 'swords': ['▁', 'N', 'o', 't']},
#  '▁word': {'freq': 56, 'swords': ['▁', 'w', 'o', 'r', 'd']},
#  '▁went': {'freq': 628, 'swords': ['▁', 'w', 'e', 'n', 't']},
#  '▁by': {'freq': 1196, 'swords': ['▁', 'b', 'y']},
#  '▁shore': {'freq': 66, 'swords': ['▁', 's', 'h', 'o', 'r', 'e']},
#  '▁sounding': {'freq': 8,
#   'swords': ['▁', 's', 'o', 'u', 'n', 'd', 'i', 'n', 'g']},
#  '▁sea': {'freq': 341, 'swords': ['▁', 's', 'e', 'a']},
#  '▁prayed': {'freq': 63, 'swords': ['▁', 'p', 'r', 'a', 'y', 'e', 'd']},
#  '▁apart': {'freq': 21, 'swords': ['▁', 'a', 'p', 'a', 'r', 't']},
#  '▁King': {'freq': 134, 'swords': ['▁', 'K', 'i', 'n', 'g']},
#  '▁whom': {'freq': 245, 'swords': ['▁', 'w', 'h', 'o', 'm']},
#  '▁lovely': {'freq': 37, 'swords': ['▁', 'l', 'o', 'v', 'e', 'l', 'y']},
#  '▁borne': {'freq': 32, 'swords': ['▁', 'b', 'o', 'r', 'n', 'e']},
#  '▁Hear': {'freq': 29, 'swords': ['▁', 'H', 'e', 'a', 'r']},
#  '▁silver': {'freq': 79, 'swords': ['▁', 's', 'i', 'l', 'v', 'e', 'r']},
#  '▁bow': {'freq': 128, 'swords': ['▁', 'b', 'o', 'w']},
#  '▁protectest': {'freq': 2,
#   'swords': ['▁', 'p', 'r', 'o', 't', 'e', 'c', 't', 'e', 's', 't']},
#  '▁Chryse': {'freq': 5, 'swords': ['▁', 'C', 'h', 'r', 'y', 's', 'e']},
#  '▁holy': {'freq': 14, 'swords': ['▁', 'h', 'o', 'l', 'y']},
#  '▁Cilla': {'freq': 2, 'swords': ['▁', 'C', 'i', 'l', 'l', 'a']},
#  '▁rulest': {'freq': 6, 'swords': ['▁', 'r', 'u', 'l', 'e', 's', 't']},
#  '▁Tenedos': {'freq': 5, 'swords': ['▁', 'T', 'e', 'n', 'e', 'd', 'o', 's']},
#  '▁thy': {'freq': 5, 'swords': ['▁', 't', 'h', 'y']},
#  '▁might': {'freq': 258, 'swords': ['▁', 'm', 'i', 'g', 'h', 't']},
#  '▁hear': {'freq': 103, 'swords': ['▁', 'h', 'e', 'a', 'r']},
#  '▁oh': {'freq': 2, 'swords': ['▁', 'o', 'h']},
#  '▁thou': {'freq': 6, 'swords': ['▁', 't', 'h', 'o', 'u']},
#  '▁Sminthe': {'freq': 1, 'swords': ['▁', 'S', 'm', 'i', 'n', 't', 'h', 'e']},
#  '▁If': {'freq': 150, 'swords': ['▁', 'I', 'f']},
#  '▁have': {'freq': 1504, 'swords': ['▁', 'h', 'a', 'v', 'e']},
#  '▁ever': {'freq': 199, 'swords': ['▁', 'e', 'v', 'e', 'r']},
#  '▁decked': {'freq': 2, 'swords': ['▁', 'd', 'e', 'c', 'k', 'e', 'd']},
#  '▁temple': {'freq': 19, 'swords': ['▁', 't', 'e', 'm', 'p', 'l', 'e']},
#  '▁garlands': {'freq': 2,
#   'swords': ['▁', 'g', 'a', 'r', 'l', 'a', 'n', 'd', 's']},
#  '▁burned': {'freq': 20, 'swords': ['▁', 'b', 'u', 'r', 'n', 'e', 'd']},
#  '▁thigh': {'freq': 37, 'swords': ['▁', 't', 'h', 'i', 'g', 'h']},
#  '▁-': {'freq': 5180, 'swords': ['▁', '-']},
#  '▁bones': {'freq': 47, 'swords': ['▁', 'b', 'o', 'n', 'e', 's']},
#  '▁fat': {'freq': 43, 'swords': ['▁', 'f', 'a', 't']},
#  '▁bulls': {'freq': 9, 'swords': ['▁', 'b', 'u', 'l', 'l', 's']},
#  '▁goats': {'freq': 43, 'swords': ['▁', 'g', 'o', 'a', 't', 's']},
#  '▁prayer': {'freq': 44, 'swords': ['▁', 'p', 'r', 'a', 'y', 'e', 'r']},
#  '▁arrows': {'freq': 44, 'swords': ['▁', 'a', 'r', 'r', 'o', 'w', 's']},
#  '▁avenge': {'freq': 24, 'swords': ['▁', 'a', 'v', 'e', 'n', 'g', 'e']},
#  '▁these': {'freq': 296, 'swords': ['▁', 't', 'h', 'e', 's', 'e']},
#  '▁tears': {'freq': 62, 'swords': ['▁', 't', 'e', 'a', 'r', 's']},
#  '▁Danaans': {'freq': 121, 'swords': ['▁', 'D', 'a', 'n', 'a', 'a', 'n', 's']},
#  '▁Thus': {'freq': 238, 'swords': ['▁', 'T', 'h', 'u', 's']},
#  '▁pray': {'freq': 49, 'swords': ['▁', 'p', 'r', 'a', 'y']},
#  '▁heard': {'freq': 181, 'swords': ['▁', 'h', 'e', 'a', 'r', 'd']},
#  '▁He': {'freq': 539, 'swords': ['▁', 'H', 'e']},
#  '▁came': {'freq': 481, 'swords': ['▁', 'c', 'a', 'm', 'e']},
#  '▁furious': {'freq': 37, 'swords': ['▁', 'f', 'u', 'r', 'i', 'o', 'u', 's']},
#  '▁summits': {'freq': 13, 'swords': ['▁', 's', 'u', 'm', 'm', 'i', 't', 's']},
#  '▁quiver': {'freq': 13, 'swords': ['▁', 'q', 'u', 'i', 'v', 'e', 'r']},
#  '▁shoulder': {'freq': 53,
#   'swords': ['▁', 's', 'h', 'o', 'u', 'l', 'd', 'e', 'r']},
#  '▁rattled': {'freq': 2, 'swords': ['▁', 'r', 'a', 't', 't', 'l', 'e', 'd']},
#  '▁back': {'freq': 470, 'swords': ['▁', 'b', 'a', 'c', 'k']},
#  '▁rage': {'freq': 39, 'swords': ['▁', 'r', 'a', 'g', 'e']},
#  '▁trembled': {'freq': 9,
#   'swords': ['▁', 't', 'r', 'e', 'm', 'b', 'l', 'e', 'd']},
#  '▁within': {'freq': 106, 'swords': ['▁', 'w', 'i', 't', 'h', 'i', 'n']},
#  '▁sat': {'freq': 112, 'swords': ['▁', 's', 'a', 't']},
#  '▁himself': {'freq': 241, 'swords': ['▁', 'h', 'i', 'm', 's', 'e', 'l', 'f']},
#  '▁face': {'freq': 118, 'swords': ['▁', 'f', 'a', 'c', 'e']},
#  '▁as': {'freq': 2247, 'swords': ['▁', 'a', 's']},
#  '▁dark': {'freq': 71, 'swords': ['▁', 'd', 'a', 'r', 'k']},
#  '▁night': {'freq': 143, 'swords': ['▁', 'n', 'i', 'g', 'h', 't']},
#  '▁rang': {'freq': 37, 'swords': ['▁', 'r', 'a', 'n', 'g']},
#  '▁death': {'freq': 175, 'swords': ['▁', 'd', 'e', 'a', 't', 'h']},
#  '▁shot': {'freq': 14, 'swords': ['▁', 's', 'h', 'o', 't']},
#  '▁arrow': {'freq': 93, 'swords': ['▁', 'a', 'r', 'r', 'o', 'w']},
#  '▁midst': {'freq': 24, 'swords': ['▁', 'm', 'i', 'd', 's', 't']},
#  '▁First': {'freq': 46, 'swords': ['▁', 'F', 'i', 'r', 's', 't']},
#  '▁smote': {'freq': 30, 'swords': ['▁', 's', 'm', 'o', 't', 'e']},
#  '▁mules': {'freq': 35, 'swords': ['▁', 'm', 'u', 'l', 'e', 's']},
#  '▁hounds': {'freq': 31, 'swords': ['▁', 'h', 'o', 'u', 'n', 'd', 's']},
#  '▁presently': {'freq': 58,
#   'swords': ['▁', 'p', 'r', 'e', 's', 'e', 'n', 't', 'l', 'y']},
#  '▁aimed': {'freq': 36, 'swords': ['▁', 'a', 'i', 'm', 'e', 'd']},
#  '▁shafts': {'freq': 5, 'swords': ['▁', 's', 'h', 'a', 'f', 't', 's']},
#  '▁themselves': {'freq': 120,
#   'swords': ['▁', 't', 'h', 'e', 'm', 's', 'e', 'l', 'v', 'e', 's']},
#  '▁long': {'freq': 271, 'swords': ['▁', 'l', 'o', 'n', 'g']},
#  '▁pyres': {'freq': 1, 'swords': ['▁', 'p', 'y', 'r', 'e', 's']},
#  '▁dead': {'freq': 178, 'swords': ['▁', 'd', 'e', 'a', 'd']},
#  '▁burning': {'freq': 29, 'swords': ['▁', 'b', 'u', 'r', 'n', 'i', 'n', 'g']},
#  '▁For': {'freq': 60, 'swords': ['▁', 'F', 'o', 'r']},
#  '▁nine': {'freq': 38, 'swords': ['▁', 'n', 'i', 'n', 'e']},
#  '▁whole': {'freq': 124, 'swords': ['▁', 'w', 'h', 'o', 'l', 'e']},
#  '▁days': {'freq': 71, 'swords': ['▁', 'd', 'a', 'y', 's']},
#  '▁among': {'freq': 426, 'swords': ['▁', 'a', 'm', 'o', 'n', 'g']},
#  '▁tenth': {'freq': 15, 'swords': ['▁', 't', 'e', 'n', 't', 'h']},
#  '▁called': {'freq': 95, 'swords': ['▁', 'c', 'a', 'l', 'l', 'e', 'd']},
#  '▁assembly': {'freq': 47,
#   'swords': ['▁', 'a', 's', 's', 'e', 'm', 'b', 'l', 'y']},
#  '▁moved': {'freq': 21, 'swords': ['▁', 'm', 'o', 'v', 'e', 'd']},
#  '▁thereto': {'freq': 2, 'swords': ['▁', 't', 'h', 'e', 'r', 'e', 't', 'o']},
#  '▁Juno': {'freq': 125, 'swords': ['▁', 'J', 'u', 'n', 'o']},
#  '▁saw': {'freq': 266, 'swords': ['▁', 's', 'a', 'w']},
#  '▁throes': {'freq': 2, 'swords': ['▁', 't', 'h', 'r', 'o', 'e', 's']},
#  '▁compassion': {'freq': 12,
#   'swords': ['▁', 'c', 'o', 'm', 'p', 'a', 's', 's', 'i', 'o', 'n']},
#  '▁Then': {'freq': 478, 'swords': ['▁', 'T', 'h', 'e', 'n']},
#  '▁when': {'freq': 1031, 'swords': ['▁', 'w', 'h', 'e', 'n']},
#  '▁they': {'freq': 1830, 'swords': ['▁', 't', 'h', 'e', 'y']},
#  '▁got': {'freq': 224, 'swords': ['▁', 'g', 'o', 't']},
#  '▁together': {'freq': 91,
#   'swords': ['▁', 't', 'o', 'g', 'e', 't', 'h', 'e', 'r']},
#  '▁rose': {'freq': 77, 'swords': ['▁', 'r', 'o', 's', 'e']},
#  '▁Son': {'freq': 44, 'swords': ['▁', 'S', 'o', 'n']},
#  '▁deem': {'freq': 6, 'swords': ['▁', 'd', 'e', 'e', 'm']},
#  '▁we': {'freq': 785, 'swords': ['▁', 'w', 'e']},
#  '▁should': {'freq': 424, 'swords': ['▁', 's', 'h', 'o', 'u', 'l', 'd']},
#  '▁now': {'freq': 645, 'swords': ['▁', 'n', 'o', 'w']},
#  '▁turn': {'freq': 97, 'swords': ['▁', 't', 'u', 'r', 'n']},
#  '▁roving': {'freq': 2, 'swords': ['▁', 'r', 'o', 'v', 'i', 'n', 'g']},
#  '▁if': {'freq': 506, 'swords': ['▁', 'i', 'f']},
#  '▁would': {'freq': 697, 'swords': ['▁', 'w', 'o', 'u', 'l', 'd']},
#  '▁escape': {'freq': 55, 'swords': ['▁', 'e', 's', 'c', 'a', 'p', 'e']},
#  '▁destruction': {'freq': 52,
#   'swords': ['▁', 'd', 'e', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n']},
#  '▁are': {'freq': 1093, 'swords': ['▁', 'a', 'r', 'e']},
#  '▁being': {'freq': 146, 'swords': ['▁', 'b', 'e', 'i', 'n', 'g']},
#  '▁cut': {'freq': 97, 'swords': ['▁', 'c', 'u', 't']},
#  '▁war': {'freq': 89, 'swords': ['▁', 'w', 'a', 'r']},
#  '▁once': {'freq': 229, 'swords': ['▁', 'o', 'n', 'c', 'e']},
#  '▁Let': {'freq': 95, 'swords': ['▁', 'L', 'e', 't']},
#  '▁us': {'freq': 610, 'swords': ['▁', 'u', 's']},
#  '▁ask': {'freq': 66, 'swords': ['▁', 'a', 's', 'k']},
#  '▁some': {'freq': 482, 'swords': ['▁', 's', 'o', 'm', 'e']},
#  '▁prophet': {'freq': 13, 'swords': ['▁', 'p', 'r', 'o', 'p', 'h', 'e', 't']},
#  '▁reader': {'freq': 3, 'swords': ['▁', 'r', 'e', 'a', 'd', 'e', 'r']},
#  '▁dreams': {'freq': 9, 'swords': ['▁', 'd', 'r', 'e', 'a', 'm', 's']},
#  '▁(': {'freq': 34, 'swords': ['▁', '(']},
#  '▁too': {'freq': 180, 'swords': ['▁', 't', 'o', 'o']},
#  '▁)': {'freq': 34, 'swords': ['▁', ')']},
#  '▁can': {'freq': 438, 'swords': ['▁', 'c', 'a', 'n']},
#  '▁tell': {'freq': 306, 'swords': ['▁', 't', 'e', 'l', 'l']},
#  '▁why': {'freq': 68, 'swords': ['▁', 'w', 'h', 'y']},
#  '▁Phoebus': {'freq': 39, 'swords': ['▁', 'P', 'h', 'o', 'e', 'b', 'u', 's']},
#  '▁is': {'freq': 1545, 'swords': ['▁', 'i', 's']},
#  '▁say': {'freq': 211, 'swords': ['▁', 's', 'a', 'y']},
#  '▁whether': {'freq': 174, 'swords': ['▁', 'w', 'h', 'e', 't', 'h', 'e', 'r']},
#  '▁vow': {'freq': 6, 'swords': ['▁', 'v', 'o', 'w']},
#  '▁broken': {'freq': 26, 'swords': ['▁', 'b', 'r', 'o', 'k', 'e', 'n']},
#  '▁hecatomb': {'freq': 16,
#   'swords': ['▁', 'h', 'e', 'c', 'a', 't', 'o', 'm', 'b']},
#  '▁savour': {'freq': 7, 'swords': ['▁', 's', 'a', 'v', 'o', 'u', 'r']},
#  '▁lambs': {'freq': 21, 'swords': ['▁', 'l', 'a', 'm', 'b', 's']},
#  '▁without': {'freq': 192, 'swords': ['▁', 'w', 'i', 't', 'h', 'o', 'u', 't']},
#  '▁blemish': {'freq': 2, 'swords': ['▁', 'b', 'l', 'e', 'm', 'i', 's', 'h']},
#  '▁take': {'freq': 405, 'swords': ['▁', 't', 'a', 'k', 'e']},
#  '▁With': {'freq': 115, 'swords': ['▁', 'W', 'i', 't', 'h']},
#  '▁words': {'freq': 128, 'swords': ['▁', 'w', 'o', 'r', 'd', 's']},
#  '▁Calchas': {'freq': 7, 'swords': ['▁', 'C', 'a', 'l', 'c', 'h', 'a', 's']},
#  '▁Thestor': {'freq': 4, 'swords': ['▁', 'T', 'h', 'e', 's', 't', 'o', 'r']},
#  '▁wisest': {'freq': 6, 'swords': ['▁', 'w', 'i', 's', 'e', 's', 't']},
#  '▁augurs': {'freq': 2, 'swords': ['▁', 'a', 'u', 'g', 'u', 'r', 's']},
#  '▁knew': {'freq': 75, 'swords': ['▁', 'k', 'n', 'e', 'w']},
#  '▁things': {'freq': 107, 'swords': ['▁', 't', 'h', 'i', 'n', 'g', 's']},
#  '▁past': {'freq': 29, 'swords': ['▁', 'p', 'a', 's', 't']},
#  '▁present': {'freq': 54, 'swords': ['▁', 'p', 'r', 'e', 's', 'e', 'n', 't']},
#  '▁speak': {'freq': 138, 'swords': ['▁', 's', 'p', 'e', 'a', 'k']},
#  '▁guided': {'freq': 9, 'swords': ['▁', 'g', 'u', 'i', 'd', 'e', 'd']},
#  '▁fleet': {'freq': 93, 'swords': ['▁', 'f', 'l', 'e', 'e', 't']},
#  '▁Ilius': {'freq': 99, 'swords': ['▁', 'I', 'l', 'i', 'u', 's']},
#  '▁through': {'freq': 303, 'swords': ['▁', 't', 'h', 'r', 'o', 'u', 'g', 'h']},
#  '▁prophesyings': {'freq': 3,
#   'swords': ['▁', 'p', 'r', 'o', 'p', 'h', 'e', 's', 'y', 'i', 'n', 'g', 's']},
#  '▁inspired': {'freq': 10,
#   'swords': ['▁', 'i', 'n', 's', 'p', 'i', 'r', 'e', 'd']},
#  '▁sincerity': {'freq': 9,
#   'swords': ['▁', 's', 'i', 'n', 'c', 'e', 'r', 'i', 't', 'y']},
#  '▁goodwill': {'freq': 15,
#   'swords': ['▁', 'g', 'o', 'o', 'd', 'w', 'i', 'l', 'l']},
#  '▁addressed': {'freq': 18,
#   'swords': ['▁', 'a', 'd', 'd', 'r', 'e', 's', 's', 'e', 'd']},
#  '▁thus': {'freq': 197, 'swords': ['▁', 't', 'h', 'u', 's']},
#  '▁loved': {'freq': 29, 'swords': ['▁', 'l', 'o', 'v', 'e', 'd']},
#  '▁heaven': {'freq': 316, 'swords': ['▁', 'h', 'e', 'a', 'v', 'e', 'n']},
#  '▁bid': {'freq': 68, 'swords': ['▁', 'b', 'i', 'd']},
#  '▁therefore': {'freq': 282,
#   'swords': ['▁', 't', 'h', 'e', 'r', 'e', 'f', 'o', 'r', 'e']},
#  '▁consider': {'freq': 18,
#   'swords': ['▁', 'c', 'o', 'n', 's', 'i', 'd', 'e', 'r']},
#  '▁swear': {'freq': 28, 'swords': ['▁', 's', 'w', 'e', 'a', 'r']},
#  '▁stand': {'freq': 123, 'swords': ['▁', 's', 't', 'a', 'n', 'd']},
#  '▁heartily': {'freq': 9,
#   'swords': ['▁', 'h', 'e', 'a', 'r', 't', 'i', 'l', 'y']},
#  '▁deed': {'freq': 19, 'swords': ['▁', 'd', 'e', 'e', 'd']},
#  '▁know': {'freq': 221, 'swords': ['▁', 'k', 'n', 'o', 'w']},
#  '▁offend': {'freq': 2, 'swords': ['▁', 'o', 'f', 'f', 'e', 'n', 'd']},
#  '▁rules': {'freq': 4, 'swords': ['▁', 'r', 'u', 'l', 'e', 's']},
#  '▁Argives': {'freq': 157, 'swords': ['▁', 'A', 'r', 'g', 'i', 'v', 'e', 's']},
#  '▁subjection': {'freq': 4,
#   'swords': ['▁', 's', 'u', 'b', 'j', 'e', 'c', 't', 'i', 'o', 'n']},
#  '▁A': {'freq': 45, 'swords': ['▁', 'A']},
#  '▁plain': {'freq': 107, 'swords': ['▁', 'p', 'l', 'a', 'i', 'n']},
#  '▁cannot': {'freq': 126, 'swords': ['▁', 'c', 'a', 'n', 'n', 'o', 't']},
#  '▁against': {'freq': 265, 'swords': ['▁', 'a', 'g', 'a', 'i', 'n', 's', 't']},
#  '▁swallow': {'freq': 7, 'swords': ['▁', 's', 'w', 'a', 'l', 'l', 'o', 'w']},
#  '▁displeasure': {'freq': 13,
#   'swords': ['▁', 'd', 'i', 's', 'p', 'l', 'e', 'a', 's', 'u', 'r', 'e']},
#  '▁nurse': {'freq': 26, 'swords': ['▁', 'n', 'u', 'r', 's', 'e']},
#  '▁revenge': {'freq': 28, 'swords': ['▁', 'r', 'e', 'v', 'e', 'n', 'g', 'e']},
#  '▁till': {'freq': 324, 'swords': ['▁', 't', 'i', 'l', 'l']},
#  '▁has': {'freq': 671, 'swords': ['▁', 'h', 'a', 's']},
#  '▁wreaked': {'freq': 1, 'swords': ['▁', 'w', 'r', 'e', 'a', 'k', 'e', 'd']},
#  '▁Consider': {'freq': 4,
#   'swords': ['▁', 'C', 'o', 'n', 's', 'i', 'd', 'e', 'r']},
#  '▁no': {'freq': 694, 'swords': ['▁', 'n', 'o']},
#  '▁protect': {'freq': 33, 'swords': ['▁', 'p', 'r', 'o', 't', 'e', 'c', 't']},
#  '▁answered': {'freq': 300,
#   'swords': ['▁', 'a', 'n', 's', 'w', 'e', 'r', 'e', 'd']},
#  '▁Fear': {'freq': 8, 'swords': ['▁', 'F', 'e', 'a', 'r']},
#  '▁whose': {'freq': 101, 'swords': ['▁', 'w', 'h', 'o', 's', 'e']},
#  '▁oracles': {'freq': 5, 'swords': ['▁', 'o', 'r', 'a', 'c', 'l', 'e', 's']},
#  '▁reveal': {'freq': 1, 'swords': ['▁', 'r', 'e', 'v', 'e', 'a', 'l']},
#  '▁Danaan': {'freq': 14, 'swords': ['▁', 'D', 'a', 'n', 'a', 'a', 'n']},
#  '▁lay': {'freq': 161, 'swords': ['▁', 'l', 'a', 'y']},
#  '▁while': {'freq': 457, 'swords': ['▁', 'w', 'h', 'i', 'l', 'e']},
#  '▁live': {'freq': 92, 'swords': ['▁', 'l', 'i', 'v', 'e']},
#  '▁look': {'freq': 102, 'swords': ['▁', 'l', 'o', 'o', 'k']},
#  '▁earth': {'freq': 135, 'swords': ['▁', 'e', 'a', 'r', 't', 'h']},
#  '▁though': {'freq': 338, 'swords': ['▁', 't', 'h', 'o', 'u', 'g', 'h']},
#  '▁name': {'freq': 76, 'swords': ['▁', 'n', 'a', 'm', 'e']},
#  '▁foremost': {'freq': 62,
#   'swords': ['▁', 'f', 'o', 'r', 'e', 'm', 'o', 's', 't']},
#  '▁Thereon': {'freq': 36, 'swords': ['▁', 'T', 'h', 'e', 'r', 'e', 'o', 'n']},
#  '▁seer': {'freq': 10, 'swords': ['▁', 's', 'e', 'e', 'r']},
#  '▁boldly': {'freq': 5, 'swords': ['▁', 'b', 'o', 'l', 'd', 'l', 'y']},
#  '▁neither': {'freq': 127, 'swords': ['▁', 'n', 'e', 'i', 't', 'h', 'e', 'r']},
#  '▁sake': {'freq': 26, 'swords': ['▁', 's', 'a', 'k', 'e']},
#  '▁evils': {'freq': 3, 'swords': ['▁', 'e', 'v', 'i', 'l', 's']},
#  '▁others': {'freq': 206, 'swords': ['▁', 'o', 't', 'h', 'e', 'r', 's']},
#  '▁deliver': {'freq': 7, 'swords': ['▁', 'd', 'e', 'l', 'i', 'v', 'e', 'r']},
#  '▁restored': {'freq': 3,
#   'swords': ['▁', 'r', 'e', 's', 't', 'o', 'r', 'e', 'd']},
#  '▁girl': {'freq': 37, 'swords': ['▁', 'g', 'i', 'r', 'l']},
#  '▁fee': {'freq': 1, 'swords': ['▁', 'f', 'e', 'e']},
#  '▁father': {'freq': 403, 'swords': ['▁', 'f', 'a', 't', 'h', 'e', 'r']},
#  '▁perhaps': {'freq': 4, 'swords': ['▁', 'p', 'e', 'r', 'h', 'a', 'p', 's']},
#  '▁appease': {'freq': 5, 'swords': ['▁', 'a', 'p', 'p', 'e', 'a', 's', 'e']},
#  '▁His': {'freq': 65, 'swords': ['▁', 'H', 'i', 's']},
#  '▁heart': {'freq': 236, 'swords': ['▁', 'h', 'e', 'a', 'r', 't']},
#  '▁black': {'freq': 36, 'swords': ['▁', 'b', 'l', 'a', 'c', 'k']},
#  '▁eyes': {'freq': 159, 'swords': ['▁', 'e', 'y', 'e', 's']},
#  '▁flashed': {'freq': 7, 'swords': ['▁', 'f', 'l', 'a', 's', 'h', 'e', 'd']},
#  '▁fire': {'freq': 163, 'swords': ['▁', 'f', 'i', 'r', 'e']},
#  '▁scowled': {'freq': 7, 'swords': ['▁', 's', 'c', 'o', 'w', 'l', 'e', 'd']},
#  '▁Seer': {'freq': 1, 'swords': ['▁', 'S', 'e', 'e', 'r']},
#  '▁evil': {'freq': 56, 'swords': ['▁', 'e', 'v', 'i', 'l']},
#  '▁never': {'freq': 203, 'swords': ['▁', 'n', 'e', 'v', 'e', 'r']},
#  '▁prophesied': {'freq': 3,
#   'swords': ['▁', 'p', 'r', 'o', 'p', 'h', 'e', 's', 'i', 'e', 'd']},
#  '▁smooth': {'freq': 9, 'swords': ['▁', 's', 'm', 'o', 'o', 't', 'h']},
#  '▁concerning': {'freq': 6,
#   'swords': ['▁', 'c', 'o', 'n', 'c', 'e', 'r', 'n', 'i', 'n', 'g']},
#  '▁foretell': {'freq': 3,
#   'swords': ['▁', 'f', 'o', 'r', 'e', 't', 'e', 'l', 'l']},
#  '▁You': {'freq': 195, 'swords': ['▁', 'Y', 'o', 'u']},
#  '▁comfort': {'freq': 17, 'swords': ['▁', 'c', 'o', 'm', 'f', 'o', 'r', 't']},
#  '▁performance': {'freq': 1,
#   'swords': ['▁', 'p', 'e', 'r', 'f', 'o', 'r', 'm', 'a', 'n', 'c', 'e']},
#  '▁seeing': {'freq': 44, 'swords': ['▁', 's', 'e', 'e', 'i', 'n', 'g']},
#  '▁saying': {'freq': 225, 'swords': ['▁', 's', 'a', 'y', 'i', 'n', 'g']},
#  '▁plagued': {'freq': 2, 'swords': ['▁', 'p', 'l', 'a', 'g', 'u', 'e', 'd']},
#  '▁keeping': {'freq': 28, 'swords': ['▁', 'k', 'e', 'e', 'p', 'i', 'n', 'g']},
#  '▁love': {'freq': 38, 'swords': ['▁', 'l', 'o', 'v', 'e']},
#  '▁better': {'freq': 135, 'swords': ['▁', 'b', 'e', 't', 't', 'e', 'r']},
#  '▁even': {'freq': 427, 'swords': ['▁', 'e', 'v', 'e', 'n']},
#  '▁than': {'freq': 275, 'swords': ['▁', 't', 'h', 'a', 'n']},
#  '▁wife': {'freq': 147, 'swords': ['▁', 'w', 'i', 'f', 'e']},
#  '▁Clytemnestra': {'freq': 4,
#   'swords': ['▁', 'C', 'l', 'y', 't', 'e', 'm', 'n', 'e', 's', 't', 'r', 'a']},
#  '▁peer': {'freq': 31, 'swords': ['▁', 'p', 'e', 'e', 'r']},
#  '▁she': {'freq': 849, 'swords': ['▁', 's', 'h', 'e']},
#  '▁alike': {'freq': 34, 'swords': ['▁', 'a', 'l', 'i', 'k', 'e']},
#  '▁form': {'freq': 28, 'swords': ['▁', 'f', 'o', 'r', 'm']},
#  '▁feature': {'freq': 1, 'swords': ['▁', 'f', 'e', 'a', 't', 'u', 'r', 'e']},
#  '▁understanding': {'freq': 24,
#   'swords': ['▁',
#    'u',
#    'n',
#    'd',
#    'e',
#    'r',
#    's',
#    't',
#    'a',
#    'n',
#    'd',
#    'i',
#    'n',
#    'g']},
#  '▁accomplishments': {'freq': 4,
#   'swords': ['▁',
#    'a',
#    'c',
#    'c',
#    'o',
#    'm',
#    'p',
#    'l',
#    'i',
#    's',
#    'h',
#    'm',
#    'e',
#    'n',
#    't',
#    's']},
#  '▁Still': {'freq': 29, 'swords': ['▁', 'S', 't', 'i', 'l', 'l']},
#  '▁give': {'freq': 287, 'swords': ['▁', 'g', 'i', 'v', 'e']},
#  '▁up': {'freq': 646, 'swords': ['▁', 'u', 'p']},
#  '▁must': {'freq': 195, 'swords': ['▁', 'm', 'u', 's', 't']},
#  '▁die': {'freq': 50, 'swords': ['▁', 'd', 'i', 'e']},
#  '▁prize': {'freq': 46, 'swords': ['▁', 'p', 'r', 'i', 'z', 'e']},
#  '▁instead': {'freq': 13, 'swords': ['▁', 'i', 'n', 's', 't', 'e', 'a', 'd']},
#  '▁alone': {'freq': 93, 'swords': ['▁', 'a', 'l', 'o', 'n', 'e']},
#  '▁This': {'freq': 126, 'swords': ['▁', 'T', 'h', 'i', 's']},
#  '▁well': {'freq': 230, 'swords': ['▁', 'w', 'e', 'l', 'l']},
#  '▁behold': {'freq': 16, 'swords': ['▁', 'b', 'e', 'h', 'o', 'l', 'd']},
#  '▁elsewhither': {'freq': 4,
#   'swords': ['▁', 'e', 'l', 's', 'e', 'w', 'h', 'i', 't', 'h', 'e', 'r']},
#  '▁Most': {'freq': 8, 'swords': ['▁', 'M', 'o', 's', 't']},
#  '▁noble': {'freq': 156, 'swords': ['▁', 'n', 'o', 'b', 'l', 'e']},
#  '▁covetous': {'freq': 1,
#   'swords': ['▁', 'c', 'o', 'v', 'e', 't', 'o', 'u', 's']},
#  '▁beyond': {'freq': 40, 'swords': ['▁', 'b', 'e', 'y', 'o', 'n', 'd']},
#  '▁mankind': {'freq': 33, 'swords': ['▁', 'm', 'a', 'n', 'k', 'i', 'n', 'd']},
#  '▁how': {'freq': 233, 'swords': ['▁', 'h', 'o', 'w']},
#  '▁We': {'freq': 113, 'swords': ['▁', 'W', 'e']},
#  '▁common': {'freq': 18, 'swords': ['▁', 'c', 'o', 'm', 'm', 'o', 'n']},
#  '▁store': {'freq': 42, 'swords': ['▁', 's', 't', 'o', 'r', 'e']},
#  '▁Those': {'freq': 11, 'swords': ['▁', 'T', 'h', 'o', 's', 'e']},
#  '▁took': {'freq': 403, 'swords': ['▁', 't', 'o', 'o', 'k']},
#  '▁cities': {'freq': 31, 'swords': ['▁', 'c', 'i', 't', 'i', 'e', 's']},
#  '▁been': {'freq': 493, 'swords': ['▁', 'b', 'e', 'e', 'n']},
#  '▁awarded': {'freq': 7, 'swords': ['▁', 'a', 'w', 'a', 'r', 'd', 'e', 'd']},
#  '▁disallow': {'freq': 1,
#   'swords': ['▁', 'd', 'i', 's', 'a', 'l', 'l', 'o', 'w']},
#  '▁awards': {'freq': 1, 'swords': ['▁', 'a', 'w', 'a', 'r', 'd', 's']},
#  '▁made': {'freq': 421, 'swords': ['▁', 'm', 'a', 'd', 'e']},
#  '▁already': {'freq': 69, 'swords': ['▁', 'a', 'l', 'r', 'e', 'a', 'd', 'y']},
#  '▁Give': {'freq': 7, 'swords': ['▁', 'G', 'i', 'v', 'e']},
#  '▁grants': {'freq': 3, 'swords': ['▁', 'g', 'r', 'a', 'n', 't', 's']},
#  '▁Troy': {'freq': 152, 'swords': ['▁', 'T', 'r', 'o', 'y']},
#  '▁requite': {'freq': 5, 'swords': ['▁', 'r', 'e', 'q', 'u', 'i', 't', 'e']},
#  '▁three': {'freq': 71, 'swords': ['▁', 't', 'h', 'r', 'e', 'e']},
#  '▁fourfold': {'freq': 1,
#   'swords': ['▁', 'f', 'o', 'u', 'r', 'f', 'o', 'l', 'd']},
#  '▁valiant': {'freq': 60, 'swords': ['▁', 'v', 'a', 'l', 'i', 'a', 'n', 't']},
#  '▁outwit': {'freq': 2, 'swords': ['▁', 'o', 'u', 't', 'w', 'i', 't']},
#  '▁overreach': {'freq': 1,
#   'swords': ['▁', 'o', 'v', 'e', 'r', 'r', 'e', 'a', 'c', 'h']},
#  '▁persuade': {'freq': 17,
#   'swords': ['▁', 'p', 'e', 'r', 's', 'u', 'a', 'd', 'e']},
#  '▁Are': {'freq': 24, 'swords': ['▁', 'A', 'r', 'e']},
#  '▁keep': {'freq': 143, 'swords': ['▁', 'k', 'e', 'e', 'p']},
#  '▁sit': {'freq': 56, 'swords': ['▁', 's', 'i', 't']},
#  '▁tamely': {'freq': 3, 'swords': ['▁', 't', 'a', 'm', 'e', 'l', 'y']},
#  '▁under': {'freq': 226, 'swords': ['▁', 'u', 'n', 'd', 'e', 'r']},
#  '▁loss': {'freq': 23, 'swords': ['▁', 'l', 'o', 's', 's']},
#  '▁bidding': {'freq': 23, 'swords': ['▁', 'b', 'i', 'd', 'd', 'i', 'n', 'g']},
#  '▁fair': {'freq': 147, 'swords': ['▁', 'f', 'a', 'i', 'r']},
#  '▁exchange': {'freq': 5,
#   'swords': ['▁', 'e', 'x', 'c', 'h', 'a', 'n', 'g', 'e']},
#  '▁liking': {'freq': 10, 'swords': ['▁', 'l', 'i', 'k', 'i', 'n', 'g']},
#  '▁Ajax': {'freq': 183, 'swords': ['▁', 'A', 'j', 'a', 'x']},
#  '▁Ulysses': {'freq': 703, 'swords': ['▁', 'U', 'l', 'y', 's', 's', 'e', 's']},
#  '▁whomsoever': {'freq': 3,
#   'swords': ['▁', 'w', 'h', 'o', 'm', 's', 'o', 'e', 'v', 'e', 'r']},
#  '▁rue': {'freq': 11, 'swords': ['▁', 'r', 'u', 'e']},
#  '▁But': {'freq': 210, 'swords': ['▁', 'B', 'u', 't']},
#  '▁thought': {'freq': 73, 'swords': ['▁', 't', 'h', 'o', 'u', 'g', 'h', 't']},
#  '▁draw': {'freq': 63, 'swords': ['▁', 'd', 'r', 'a', 'w']},
#  '▁ship': {'freq': 297, 'swords': ['▁', 's', 'h', 'i', 'p']},
#  '▁into': {'freq': 615, 'swords': ['▁', 'i', 'n', 't', 'o']},
#  '▁crew': {'freq': 46, 'swords': ['▁', 'c', 'r', 'e', 'w']},
#  '▁expressly': {'freq': 2,
#   'swords': ['▁', 'e', 'x', 'p', 'r', 'e', 's', 's', 'l', 'y']},
#  '▁put': {'freq': 230, 'swords': ['▁', 'p', 'u', 't']},
#  '▁board': {'freq': 61, 'swords': ['▁', 'b', 'o', 'a', 'r', 'd']},
#  '▁Chryseis': {'freq': 5,
#   'swords': ['▁', 'C', 'h', 'r', 'y', 's', 'e', 'i', 's']},
#  '▁also': {'freq': 268, 'swords': ['▁', 'a', 'l', 's', 'o']},
#  '▁further': {'freq': 92, 'swords': ['▁', 'f', 'u', 'r', 't', 'h', 'e', 'r']},
#  '▁chief': {'freq': 41, 'swords': ['▁', 'c', 'h', 'i', 'e', 'f']},
#  '▁command': {'freq': 16, 'swords': ['▁', 'c', 'o', 'm', 'm', 'a', 'n', 'd']},
#  '▁either': {'freq': 123, 'swords': ['▁', 'e', 'i', 't', 'h', 'e', 'r']},
#  '▁Idomeneus': {'freq': 84,
#   'swords': ['▁', 'I', 'd', 'o', 'm', 'e', 'n', 'e', 'u', 's']},
#  '▁yourself': {'freq': 135,
#   'swords': ['▁', 'y', 'o', 'u', 'r', 's', 'e', 'l', 'f']},
#  '▁mighty': {'freq': 127, 'swords': ['▁', 'm', 'i', 'g', 'h', 't', 'y']},
#  '▁warrior': {'freq': 26, 'swords': ['▁', 'w', 'a', 'r', 'r', 'i', 'o', 'r']},
#  '▁offer': {'freq': 37, 'swords': ['▁', 'o', 'f', 'f', 'e', 'r']},
#  '▁sacrifice': {'freq': 52,
#   'swords': ['▁', 's', 'a', 'c', 'r', 'i', 'f', 'i', 'c', 'e']},
#  '▁steeped': {'freq': 3, 'swords': ['▁', 's', 't', 'e', 'e', 'p', 'e', 'd']},
#  '▁insolence': {'freq': 17,
#   'swords': ['▁', 'i', 'n', 's', 'o', 'l', 'e', 'n', 'c', 'e']},
#  '▁lust': {'freq': 9, 'swords': ['▁', 'l', 'u', 's', 't']},
#  '▁gain': {'freq': 15, 'swords': ['▁', 'g', 'a', 'i', 'n']},
#  '▁what': {'freq': 393, 'swords': ['▁', 'w', 'h', 'a', 't']},
#  '▁any': {'freq': 336, 'swords': ['▁', 'a', 'n', 'y']},
#  '▁foray': {'freq': 1, 'swords': ['▁', 'f', 'o', 'r', 'a', 'y']},
#  '▁open': {'freq': 51, 'swords': ['▁', 'o', 'p', 'e', 'n']},
#  '▁fighting': {'freq': 173,
#   'swords': ['▁', 'f', 'i', 'g', 'h', 't', 'i', 'n', 'g']},
#  '▁warring': {'freq': 2, 'swords': ['▁', 'w', 'a', 'r', 'r', 'i', 'n', 'g']},
#  '▁here': {'freq': 319, 'swords': ['▁', 'h', 'e', 'r', 'e']},
#  '▁ill': {'freq': 82, 'swords': ['▁', 'i', 'l', 'l']},
#  '▁Trojans': {'freq': 573, 'swords': ['▁', 'T', 'r', 'o', 'j', 'a', 'n', 's']},
#  '▁done': {'freq': 145, 'swords': ['▁', 'd', 'o', 'n', 'e']},
#  '▁They': {'freq': 236, 'swords': ['▁', 'T', 'h', 'e', 'y']},
#  '▁raided': {'freq': 1, 'swords': ['▁', 'r', 'a', 'i', 'd', 'e', 'd']},
#  '▁cattle': {'freq': 62, 'swords': ['▁', 'c', 'a', 't', 't', 'l', 'e']},
#  '▁horses': {'freq': 308, 'swords': ['▁', 'h', 'o', 'r', 's', 'e', 's']},
#  '▁harvests': {'freq': 1,
#   'swords': ['▁', 'h', 'a', 'r', 'v', 'e', 's', 't', 's']},
#  '▁rich': {'freq': 74, 'swords': ['▁', 'r', 'i', 'c', 'h']},
#  '▁plains': {'freq': 3, 'swords': ['▁', 'p', 'l', 'a', 'i', 'n', 's']},
#  '▁Phthia': {'freq': 18, 'swords': ['▁', 'P', 'h', 't', 'h', 'i', 'a']},
#  '▁between': {'freq': 99, 'swords': ['▁', 'b', 'e', 't', 'w', 'e', 'e', 'n']},
#  '▁there': {'freq': 601, 'swords': ['▁', 't', 'h', 'e', 'r', 'e']},
#  '▁space': {'freq': 24, 'swords': ['▁', 's', 'p', 'a', 'c', 'e']},
#  '▁both': {'freq': 300, 'swords': ['▁', 'b', 'o', 't', 'h']},
#  '▁mountain': {'freq': 62,
#   'swords': ['▁', 'm', 'o', 'u', 'n', 't', 'a', 'i', 'n']},
#  '▁followed': {'freq': 52,
#   'swords': ['▁', 'f', 'o', 'l', 'l', 'o', 'w', 'e', 'd']},
#  '▁Sir': {'freq': 44, 'swords': ['▁', 'S', 'i', 'r']},
#  '▁Insolence': {'freq': 1,
#   'swords': ['▁', 'I', 'n', 's', 'o', 'l', 'e', 'n', 'c', 'e']},
#  '▁!': {'freq': 20, 'swords': ['▁', '!']},
#  '▁pleasure': {'freq': 18,
#   'swords': ['▁', 'p', 'l', 'e', 'a', 's', 'u', 'r', 'e']},
#  '▁ours': {'freq': 11, 'swords': ['▁', 'o', 'u', 'r', 's']},
#  '▁satisfaction': {'freq': 11,
#   'swords': ['▁', 's', 'a', 't', 'i', 's', 'f', 'a', 'c', 't', 'i', 'o', 'n']},
#  '▁shameless': {'freq': 3,
#   'swords': ['▁', 's', 'h', 'a', 'm', 'e', 'l', 'e', 's', 's']},
#  '▁self': {'freq': 22, 'swords': ['▁', 's', 'e', 'l', 'f']},
#  '▁Menelaus': {'freq': 211,
#   'swords': ['▁', 'M', 'e', 'n', 'e', 'l', 'a', 'u', 's']},
#  '▁forget': {'freq': 30, 'swords': ['▁', 'f', 'o', 'r', 'g', 'e', 't']},
#  '▁threaten': {'freq': 2,
#   'swords': ['▁', 't', 'h', 'r', 'e', 'a', 't', 'e', 'n']},
#  '▁rob': {'freq': 12, 'swords': ['▁', 'r', 'o', 'b']},
#  '▁toiled': {'freq': 2, 'swords': ['▁', 't', 'o', 'i', 'l', 'e', 'd']},
#  '▁given': {'freq': 120, 'swords': ['▁', 'g', 'i', 'v', 'e', 'n']},
#  '▁Never': {'freq': 15, 'swords': ['▁', 'N', 'e', 'v', 'e', 'r']},
#  '▁receive': {'freq': 9, 'swords': ['▁', 'r', 'e', 'c', 'e', 'i', 'v', 'e']},
#  '▁good': {'freq': 295, 'swords': ['▁', 'g', 'o', 'o', 'd']},
#  '▁hands': {'freq': 328, 'swords': ['▁', 'h', 'a', 'n', 'd', 's']},
#  '▁part': {'freq': 83, 'swords': ['▁', 'p', 'a', 'r', 't']},
#  '▁When': {'freq': 356, 'swords': ['▁', 'W', 'h', 'e', 'n']},
#  '▁sharing': {'freq': 3, 'swords': ['▁', 's', 'h', 'a', 'r', 'i', 'n', 'g']},
#  '▁comes': {'freq': 69, 'swords': ['▁', 'c', 'o', 'm', 'e', 's']},
#  '▁share': {'freq': 29, 'swords': ['▁', 's', 'h', 'a', 'r', 'e']},
#  '▁largest': {'freq': 7, 'swords': ['▁', 'l', 'a', 'r', 'g', 'e', 's', 't']},
#  '▁forsooth': {'freq': 6,
#   'swords': ['▁', 'f', 'o', 'r', 's', 'o', 'o', 't', 'h']},
#  '▁get': {'freq': 187, 'swords': ['▁', 'g', 'e', 't']},
#  '▁thankful': {'freq': 11,
#   'swords': ['▁', 't', 'h', 'a', 'n', 'k', 'f', 'u', 'l']},
#  '▁labour': {'freq': 21, 'swords': ['▁', 'l', 'a', 'b', 'o', 'u', 'r']},
#  '▁much': {'freq': 320, 'swords': ['▁', 'm', 'u', 'c', 'h']},
#  '▁return': {'freq': 138, 'swords': ['▁', 'r', 'e', 't', 'u', 'r', 'n']},
#  '▁stay': {'freq': 132, 'swords': ['▁', 's', 't', 'a', 'y']},
#  '▁gather': {'freq': 24, 'swords': ['▁', 'g', 'a', 't', 'h', 'e', 'r']},
#  '▁gold': {'freq': 126, 'swords': ['▁', 'g', 'o', 'l', 'd']},
#  '▁substance': {'freq': 11,
#   'swords': ['▁', 's', 'u', 'b', 's', 't', 'a', 'n', 'c', 'e']},
#  '▁Fly': {'freq': 1, 'swords': ['▁', 'F', 'l', 'y']},
#  '▁make': {'freq': 275, 'swords': ['▁', 'm', 'a', 'k', 'e']},
#  '▁prayers': {'freq': 17, 'swords': ['▁', 'p', 'r', 'a', 'y', 'e', 'r', 's']},
#  '▁honour': {'freq': 89, 'swords': ['▁', 'h', 'o', 'n', 'o', 'u', 'r']},
#  '▁above': {'freq': 55, 'swords': ['▁', 'a', 'b', 'o', 'v', 'e']},
#  '▁lord': {'freq': 68, 'swords': ['▁', 'l', 'o', 'r', 'd']},
#  '▁counsel': {'freq': 66, 'swords': ['▁', 'c', 'o', 'u', 'n', 's', 'e', 'l']},
#  '▁There': {'freq': 145, 'swords': ['▁', 'T', 'h', 'e', 'r', 'e']},
#  '▁hateful': {'freq': 10, 'swords': ['▁', 'h', 'a', 't', 'e', 'f', 'u', 'l']},
#  '▁quarrelsome': {'freq': 1,
#   'swords': ['▁', 'q', 'u', 'a', 'r', 'r', 'e', 'l', 's', 'o', 'm', 'e']},
#  '▁affected': {'freq': 2,
#   'swords': ['▁', 'a', 'f', 'f', 'e', 'c', 't', 'e', 'd']},
#  '▁What': {'freq': 55, 'swords': ['▁', 'W', 'h', 'a', 't']},
#  '▁Was': {'freq': 8, 'swords': ['▁', 'W', 'a', 's']},
#  '▁Go': {'freq': 42, 'swords': ['▁', 'G', 'o']},
#  '▁then': {'freq': 749, 'swords': ['▁', 't', 'h', 'e', 'n']},
#  '▁comrades': {'freq': 84,
#   'swords': ['▁', 'c', 'o', 'm', 'r', 'a', 'd', 'e', 's']},
#  '▁over': {'freq': 526, 'swords': ['▁', 'o', 'v', 'e', 'r']},
#  '▁Myrmidons': {'freq': 41,
#   'swords': ['▁', 'M', 'y', 'r', 'm', 'i', 'd', 'o', 'n', 's']},
#  '▁care': {'freq': 68, 'swords': ['▁', 'c', 'a', 'r', 'e']},
#  '▁since': {'freq': 40, 'swords': ['▁', 's', 'i', 'n', 'c', 'e']},
#  '▁followers': {'freq': 16,
#   'swords': ['▁', 'f', 'o', 'l', 'l', 'o', 'w', 'e', 'r', 's']},
#  '▁tent': {'freq': 54, 'swords': ['▁', 't', 'e', 'n', 't']},
#  '▁Briseis': {'freq': 13, 'swords': ['▁', 'B', 'r', 'i', 's', 'e', 'i', 's']},
#  '▁learn': {'freq': 36, 'swords': ['▁', 'l', 'e', 'a', 'r', 'n']},
#  '▁stronger': {'freq': 39,
#   'swords': ['▁', 's', 't', 'r', 'o', 'n', 'g', 'e', 'r']},
#  '▁am': {'freq': 337, 'swords': ['▁', 'a', 'm']},
#  '▁fear': {'freq': 117, 'swords': ['▁', 'f', 'e', 'a', 'r']},
#  '▁equal': {'freq': 14, 'swords': ['▁', 'e', 'q', 'u', 'a', 'l']},
#  '▁comparable': {'freq': 2,
#   'swords': ['▁', 'c', 'o', 'm', 'p', 'a', 'r', 'a', 'b', 'l', 'e']},
#  '▁shaggy': {'freq': 6, 'swords': ['▁', 's', 'h', 'a', 'g', 'g', 'y']},
#  '▁breast': {'freq': 34, 'swords': ['▁', 'b', 'r', 'e', 'a', 's', 't']},
#  '▁divided': {'freq': 22, 'swords': ['▁', 'd', 'i', 'v', 'i', 'd', 'e', 'd']},
#  '▁sword': {'freq': 101, 'swords': ['▁', 's', 'w', 'o', 'r', 'd']},
#  '▁push': {'freq': 2, 'swords': ['▁', 'p', 'u', 's', 'h']},
#  '▁aside': {'freq': 27, 'swords': ['▁', 'a', 's', 'i', 'd', 'e']},
#  '▁kill': {'freq': 105, 'swords': ['▁', 'k', 'i', 'l', 'l']},
#  '▁restrain': {'freq': 6,
#   'swords': ['▁', 'r', 'e', 's', 't', 'r', 'a', 'i', 'n']},
#  '▁check': {'freq': 17, 'swords': ['▁', 'c', 'h', 'e', 'c', 'k']},
#  '▁While': {'freq': 23, 'swords': ['▁', 'W', 'h', 'i', 'l', 'e']},
#  '▁minds': {'freq': 22, 'swords': ['▁', 'm', 'i', 'n', 'd', 's']},
#  '▁drawing': {'freq': 19, 'swords': ['▁', 'd', 'r', 'a', 'w', 'i', 'n', 'g']},
#  '▁its': {'freq': 151, 'swords': ['▁', 'i', 't', 's']},
#  '▁scabbard': {'freq': 6,
#   'swords': ['▁', 's', 'c', 'a', 'b', 'b', 'a', 'r', 'd']},
#  '▁Minerva': {'freq': 307, 'swords': ['▁', 'M', 'i', 'n', 'e', 'r', 'v', 'a']},
#  '▁seized': {'freq': 23, 'swords': ['▁', 's', 'e', 'i', 'z', 'e', 'd']},
#  '▁yellow': {'freq': 9, 'swords': ['▁', 'y', 'e', 'l', 'l', 'o', 'w']},
#  '▁hair': {'freq': 44, 'swords': ['▁', 'h', 'a', 'i', 'r']},
#  '▁visible': {'freq': 3, 'swords': ['▁', 'v', 'i', 's', 'i', 'b', 'l', 'e']},
#  '▁could': {'freq': 375, 'swords': ['▁', 'c', 'o', 'u', 'l', 'd']},
#  '▁see': {'freq': 356, 'swords': ['▁', 's', 'e', 'e']},
#  '▁turned': {'freq': 95, 'swords': ['▁', 't', 'u', 'r', 'n', 'e', 'd']},
#  '▁amaze': {'freq': 2, 'swords': ['▁', 'a', 'm', 'a', 'z', 'e']},
#  '▁Why': {'freq': 35, 'swords': ['▁', 'W', 'h', 'y']},
#  '▁aegis': {'freq': 39, 'swords': ['▁', 'a', 'e', 'g', 'i', 's']},
#  '▁bearing': {'freq': 64, 'swords': ['▁', 'b', 'e', 'a', 'r', 'i', 'n', 'g']},
#  '▁To': {'freq': 36, 'swords': ['▁', 'T', 'o']},
#  '▁pride': {'freq': 19, 'swords': ['▁', 'p', 'r', 'i', 'd', 'e']},
#  '▁surely': {'freq': 50, 'swords': ['▁', 's', 'u', 'r', 'e', 'l', 'y']},
#  '▁pay': {'freq': 28, 'swords': ['▁', 'p', 'a', 'y']},
#  '▁life': {'freq': 113, 'swords': ['▁', 'l', 'i', 'f', 'e']},
#  '▁cares': {'freq': 5, 'swords': ['▁', 'c', 'a', 'r', 'e', 's']},
#  '▁Cease': {'freq': 4, 'swords': ['▁', 'C', 'e', 'a', 's', 'e']},
#  '▁brawling': {'freq': 4,
#   'swords': ['▁', 'b', 'r', 'a', 'w', 'l', 'i', 'n', 'g']},
#  '▁rail': {'freq': 4, 'swords': ['▁', 'r', 'a', 'i', 'l']},
#  '▁railing': {'freq': 6, 'swords': ['▁', 'r', 'a', 'i', 'l', 'i', 'n', 'g']},
#  '▁vain': {'freq': 38, 'swords': ['▁', 'v', 'a', 'i', 'n']},
#  '▁gifts': {'freq': 43, 'swords': ['▁', 'g', 'i', 'f', 't', 's']},
#  '▁times': {'freq': 30, 'swords': ['▁', 't', 'i', 'm', 'e', 's']},
#  '▁splendid': {'freq': 11,
#   'swords': ['▁', 's', 'p', 'l', 'e', 'n', 'd', 'i', 'd']},
#  '▁reason': {'freq': 25, 'swords': ['▁', 'r', 'e', 'a', 's', 'o', 'n']},
#  '▁insult': {'freq': 9, 'swords': ['▁', 'i', 'n', 's', 'u', 'l', 't']},
#  '▁Hold': {'freq': 7, 'swords': ['▁', 'H', 'o', 'l', 'd']},
#  '▁obey': {'freq': 14, 'swords': ['▁', 'o', 'b', 'e', 'y']},
#  '▁Goddess': {'freq': 6, 'swords': ['▁', 'G', 'o', 'd', 'd', 'e', 's', 's']},
#  '▁however': {'freq': 143, 'swords': ['▁', 'h', 'o', 'w', 'e', 'v', 'e', 'r']},
#  '▁best': {'freq': 139, 'swords': ['▁', 'b', 'e', 's', 't']},
#  '▁stayed': {'freq': 78, 'swords': ['▁', 's', 't', 'a', 'y', 'e', 'd']},
#  '▁hilt': {'freq': 4, 'swords': ['▁', 'h', 'i', 'l', 't']},
#  '▁thrust': {'freq': 16, 'swords': ['▁', 't', 'h', 'r', 'u', 's', 't']},
#  '▁bade': {'freq': 77, 'swords': ['▁', 'b', 'a', 'd', 'e']},
#  '▁again': {'freq': 298, 'swords': ['▁', 'a', 'g', 'a', 'i', 'n']},
#  '▁began': {'freq': 117, 'swords': ['▁', 'b', 'e', 'g', 'a', 'n']},
#  '▁still': {'freq': 297, 'swords': ['▁', 's', 't', 'i', 'l', 'l']},
#  '▁Wine': {'freq': 2, 'swords': ['▁', 'W', 'i', 'n', 'e']},
#  '▁bibber': {'freq': 1, 'swords': ['▁', 'b', 'i', 'b', 'b', 'e', 'r']},
#  '▁dog': {'freq': 9, 'swords': ['▁', 'd', 'o', 'g']},
#  '▁hind': {'freq': 5, 'swords': ['▁', 'h', 'i', 'n', 'd']},
#  '▁dare': {'freq': 39, 'swords': ['▁', 'd', 'a', 'r', 'e']},
#  '▁fight': {'freq': 362, 'swords': ['▁', 'f', 'i', 'g', 'h', 't']},
#  '▁chosen': {'freq': 16, 'swords': ['▁', 'c', 'h', 'o', 's', 'e', 'n']},
#  '▁ambuscade': {'freq': 8,
#   'swords': ['▁', 'a', 'm', 'b', 'u', 's', 'c', 'a', 'd', 'e']},
#  '▁shun': {'freq': 6, 'swords': ['▁', 's', 'h', 'u', 'n']},
#  '▁itself': {'freq': 45, 'swords': ['▁', 'i', 't', 's', 'e', 'l', 'f']},
#  '▁rather': {'freq': 40, 'swords': ['▁', 'r', 'a', 't', 'h', 'e', 'r']},
#  '▁round': {'freq': 336, 'swords': ['▁', 'r', 'o', 'u', 'n', 'd']},
#  '▁prizes': {'freq': 22, 'swords': ['▁', 'p', 'r', 'i', 'z', 'e', 's']},
#  '▁contradicts': {'freq': 3,
#   'swords': ['▁', 'c', 'o', 'n', 't', 'r', 'a', 'd', 'i', 'c', 't', 's']},
#  '▁devour': {'freq': 14, 'swords': ['▁', 'd', 'e', 'v', 'o', 'u', 'r']},
#  '▁feeble': {'freq': 6, 'swords': ['▁', 'f', 'e', 'e', 'b', 'l', 'e']},
#  '▁folk': {'freq': 4, 'swords': ['▁', 'f', 'o', 'l', 'k']},
#  '▁otherwise': {'freq': 10,
#   'swords': ['▁', 'o', 't', 'h', 'e', 'r', 'w', 'i', 's', 'e']},
#  '▁henceforward': {'freq': 9,
#   'swords': ['▁', 'h', 'e', 'n', 'c', 'e', 'f', 'o', 'r', 'w', 'a', 'r', 'd']},
#  '▁Therefore': {'freq': 48,
#   'swords': ['▁', 'T', 'h', 'e', 'r', 'e', 'f', 'o', 'r', 'e']},
#  '▁oath': {'freq': 33, 'swords': ['▁', 'o', 'a', 't', 'h']},
#  '▁nay': {'freq': 5, 'swords': ['▁', 'n', 'a', 'y']},
#  '▁shalt': {'freq': 1, 'swords': ['▁', 's', 'h', 'a', 'l', 't']},
#  '▁sprout': {'freq': 1, 'swords': ['▁', 's', 'p', 'r', 'o', 'u', 't']},
#  '▁leaf': {'freq': 3, 'swords': ['▁', 'l', 'e', 'a', 'f']},
#  '▁shoot': {'freq': 16, 'swords': ['▁', 's', 'h', 'o', 'o', 't']},
#  '▁bud': {'freq': 1, 'swords': ['▁', 'b', 'u', 'd']},
#  '▁anew': {'freq': 7, 'swords': ['▁', 'a', 'n', 'e', 'w']},
#  '▁left': {'freq': 273, 'swords': ['▁', 'l', 'e', 'f', 't']},
#  '▁parent': {'freq': 1, 'swords': ['▁', 'p', 'a', 'r', 'e', 'n', 't']},
#  '▁stem': {'freq': 1, 'swords': ['▁', 's', 't', 'e', 'm']},
#  '▁mountains': {'freq': 32,
#   'swords': ['▁', 'm', 'o', 'u', 'n', 't', 'a', 'i', 'n', 's']},
#  '▁axe': {'freq': 9, 'swords': ['▁', 'a', 'x', 'e']},
#  '▁stripped': {'freq': 24,
#   'swords': ['▁', 's', 't', 'r', 'i', 'p', 'p', 'e', 'd']},
#  '▁bark': {'freq': 4, 'swords': ['▁', 'b', 'a', 'r', 'k']},
#  '▁bear': {'freq': 71, 'swords': ['▁', 'b', 'e', 'a', 'r']},
# ...
#  '▁mother': {'freq': 200, 'swords': ['▁', 'm', 'o', 't', 'h', 'e', 'r']},
#  '▁implore': {'freq': 6, 'swords': ['▁', 'i', 'm', 'p', 'l', 'o', 'r', 'e']},
#  '▁end': {'freq': 162, 'swords': ['▁', 'e', 'n', 'd']},
#  '▁battle': {'freq': 255, 'swords': ['▁', 'b', 'a', 't', 't', 'l', 'e']},
#  '▁tower': {'freq': 18, 'swords': ['▁', 't', 'o', 'w', 'e', 'r']},
#  '▁strength': {'freq': 101,
#   'swords': ['▁', 's', 't', 'r', 'e', 'n', 'g', 't', 'h']},
#  '▁true': {'freq': 62, 'swords': ['▁', 't', 'r', 'u', 'e']},
#  '▁fellow': {'freq': 52, 'swords': ['▁', 'f', 'e', 'l', 'l', 'o', 'w']},
#  '▁needs': {'freq': 8, 'swords': ['▁', 'n', 'e', 'e', 'd', 's']},
#  '▁become': {'freq': 33, 'swords': ['▁', 'b', 'e', 'c', 'o', 'm', 'e']},
#  '▁master': {'freq': 57, 'swords': ['▁', 'm', 'a', 's', 't', 'e', 'r']},
#  '▁captain': {'freq': 36, 'swords': ['▁', 'c', 'a', 'p', 't', 'a', 'i', 'n']},
#  '▁hardly': {'freq': 36, 'swords': ['▁', 'h', 'a', 'r', 'd', 'l', 'y']},
#  '▁Granted': {'freq': 2, 'swords': ['▁', 'G', 'r', 'a', 'n', 't', 'e', 'd']},
#  '▁right': {'freq': 157, 'swords': ['▁', 'r', 'i', 'g', 'h', 't']},
#  '▁interrupted': {'freq': 2,
#   'swords': ['▁', 'i', 'n', 't', 'e', 'r', 'r', 'u', 'p', 't', 'e', 'd']},
#  '▁mean': {'freq': 32, 'swords': ['▁', 'm', 'e', 'a', 'n']},
#  '▁coward': {'freq': 19, 'swords': ['▁', 'c', 'o', 'w', 'a', 'r', 'd']},
#  '▁Order': {'freq': 1, 'swords': ['▁', 'O', 'r', 'd', 'e', 'r']},
#  '▁longer': {'freq': 95, 'swords': ['▁', 'l', 'o', 'n', 'g', 'e', 'r']},
#  '▁Furthermore': {'freq': 13,
#   'swords': ['▁', 'F', 'u', 'r', 't', 'h', 'e', 'r', 'm', 'o', 'r', 'e']},
#  '▁those': {'freq': 190, 'swords': ['▁', 't', 'h', 'o', 's', 'e']},
#  '▁gave': {'freq': 207, 'swords': ['▁', 'g', 'a', 'v', 'e']},
#  '▁else': {'freq': 78, 'swords': ['▁', 'e', 'l', 's', 'e']},
#  '▁carry': {'freq': 45, 'swords': ['▁', 'c', 'a', 'r', 'r', 'y']},
#  '▁force': {'freq': 54, 'swords': ['▁', 'f', 'o', 'r', 'c', 'e']},
#  '▁Try': {'freq': 2, 'swords': ['▁', 'T', 'r', 'y']},
#  '▁spear': {'freq': 429, 'swords': ['▁', 's', 'p', 'e', 'a', 'r']},
#  '▁reddened': {'freq': 3,
#   'swords': ['▁', 'r', 'e', 'd', 'd', 'e', 'n', 'e', 'd']},
#  '▁blood': {'freq': 153, 'swords': ['▁', 'b', 'l', 'o', 'o', 'd']},
#  '▁quarrelled': {'freq': 4,
#   'swords': ['▁', 'q', 'u', 'a', 'r', 'r', 'e', 'l', 'l', 'e', 'd']},
#  '▁angrily': {'freq': 9, 'swords': ['▁', 'a', 'n', 'g', 'r', 'i', 'l', 'y']},
#  '▁broke': {'freq': 46, 'swords': ['▁', 'b', 'r', 'o', 'k', 'e']},
#  '▁tents': {'freq': 47, 'swords': ['▁', 't', 'e', 'n', 't', 's']},
#  '▁Menoetius': {'freq': 33,
#   'swords': ['▁', 'M', 'e', 'n', 'o', 'e', 't', 'i', 'u', 's']},
#  '▁company': {'freq': 22, 'swords': ['▁', 'c', 'o', 'm', 'p', 'a', 'n', 'y']},
#  '▁drew': {'freq': 135, 'swords': ['▁', 'd', 'r', 'e', 'w']},
#  '▁vessel': {'freq': 19, 'swords': ['▁', 'v', 'e', 's', 's', 'e', 'l']},
#  '▁water': {'freq': 160, 'swords': ['▁', 'w', 'a', 't', 'e', 'r']},
#  '▁chose': {'freq': 14, 'swords': ['▁', 'c', 'h', 'o', 's', 'e']},
#  '▁twenty': {'freq': 44, 'swords': ['▁', 't', 'w', 'e', 'n', 't', 'y']},
#  '▁oarsmen': {'freq': 6, 'swords': ['▁', 'o', 'a', 'r', 's', 'm', 'e', 'n']},
#  '▁escorted': {'freq': 3,
#   'swords': ['▁', 'e', 's', 'c', 'o', 'r', 't', 'e', 'd']},
#  '▁sailed': {'freq': 27, 'swords': ['▁', 's', 'a', 'i', 'l', 'e', 'd']},
#  '▁ways': {'freq': 22, 'swords': ['▁', 'w', 'a', 'y', 's']},
#  '▁purify': {'freq': 3, 'swords': ['▁', 'p', 'u', 'r', 'i', 'f', 'y']},
#  '▁purified': {'freq': 2,
#   'swords': ['▁', 'p', 'u', 'r', 'i', 'f', 'i', 'e', 'd']},
#  '▁cast': {'freq': 20, 'swords': ['▁', 'c', 'a', 's', 't']},
#  '▁filth': {'freq': 5, 'swords': ['▁', 'f', 'i', 'l', 't', 'h']},
#  '▁hecatombs': {'freq': 21,
#   'swords': ['▁', 'h', 'e', 'c', 'a', 't', 'o', 'm', 'b', 's']},
#  '▁smoke': {'freq': 18, 'swords': ['▁', 's', 'm', 'o', 'k', 'e']},
#  '▁curling': {'freq': 1, 'swords': ['▁', 'c', 'u', 'r', 'l', 'i', 'n', 'g']},
#  '▁towards': {'freq': 190, 'swords': ['▁', 't', 'o', 'w', 'a', 'r', 'd', 's']},
#  '▁busy': {'freq': 21, 'swords': ['▁', 'b', 'u', 's', 'y']},
#  '▁throughout': {'freq': 38,
#   'swords': ['▁', 't', 'h', 'r', 'o', 'u', 'g', 'h', 'o', 'u', 't']},
#  '▁threat': {'freq': 2, 'swords': ['▁', 't', 'h', 'r', 'e', 'a', 't']},
#  '▁trusty': {'freq': 7, 'swords': ['▁', 't', 'r', 'u', 's', 't', 'y']},
#  '▁messengers': {'freq': 9,
#   'swords': ['▁', 'm', 'e', 's', 's', 'e', 'n', 'g', 'e', 'r', 's']},
#  '▁squires': {'freq': 9, 'swords': ['▁', 's', 'q', 'u', 'i', 'r', 'e', 's']},
#  '▁Talthybius': {'freq': 10,
#   'swords': ['▁', 'T', 'a', 'l', 't', 'h', 'y', 'b', 'i', 'u', 's']},
#  '▁Eurybates': {'freq': 4,
#   'swords': ['▁', 'E', 'u', 'r', 'y', 'b', 'a', 't', 'e', 's']},
#  '▁bring': {'freq': 144, 'swords': ['▁', 'b', 'r', 'i', 'n', 'g']},
#  '▁hither': {'freq': 52, 'swords': ['▁', 'h', 'i', 't', 'h', 'e', 'r']},
#  '▁press': {'freq': 23, 'swords': ['▁', 'p', 'r', 'e', 's', 's']},
#  '▁harder': {'freq': 7, 'swords': ['▁', 'h', 'a', 'r', 'd', 'e', 'r']},
#  '▁charged': {'freq': 11, 'swords': ['▁', 'c', 'h', 'a', 'r', 'g', 'e', 'd']},
#  '▁straightly': {'freq': 1,
#   'swords': ['▁', 's', 't', 'r', 'a', 'i', 'g', 'h', 't', 'l', 'y']},
#  '▁dismissed': {'freq': 4,
#   'swords': ['▁', 'd', 'i', 's', 'm', 'i', 's', 's', 'e', 'd']},
#  '▁whereon': {'freq': 118, 'swords': ['▁', 'w', 'h', 'e', 'r', 'e', 'o', 'n']},
#  '▁sorrowfully': {'freq': 4,
#   'swords': ['▁', 's', 'o', 'r', 'r', 'o', 'w', 'f', 'u', 'l', 'l', 'y']},
#  '▁seaside': {'freq': 2, 'swords': ['▁', 's', 'e', 'a', 's', 'i', 'd', 'e']},
#  '▁found': {'freq': 106, 'swords': ['▁', 'f', 'o', 'u', 'n', 'd']},
#  '▁sitting': {'freq': 51, 'swords': ['▁', 's', 'i', 't', 't', 'i', 'n', 'g']},
#  '▁pleased': {'freq': 25, 'swords': ['▁', 'p', 'l', 'e', 'a', 's', 'e', 'd']},
#  '▁beheld': {'freq': 17, 'swords': ['▁', 'b', 'e', 'h', 'e', 'l', 'd']},
#  '▁stood': {'freq': 165, 'swords': ['▁', 's', 't', 'o', 'o', 'd']},
#  '▁fearfully': {'freq': 6,
#   'swords': ['▁', 'f', 'e', 'a', 'r', 'f', 'u', 'l', 'l', 'y']},
#  '▁reverently': {'freq': 1,
#   'swords': ['▁', 'r', 'e', 'v', 'e', 'r', 'e', 'n', 't', 'l', 'y']},
#  '▁before': {'freq': 339, 'swords': ['▁', 'b', 'e', 'f', 'o', 'r', 'e']},
#  '▁Welcome': {'freq': 2, 'swords': ['▁', 'W', 'e', 'l', 'c', 'o', 'm', 'e']},
#  '▁heralds': {'freq': 16, 'swords': ['▁', 'h', 'e', 'r', 'a', 'l', 'd', 's']},
#  '▁near': {'freq': 159, 'swords': ['▁', 'n', 'e', 'a', 'r']},
#  '▁Patroclus': {'freq': 177,
#   'swords': ['▁', 'P', 'a', 't', 'r', 'o', 'c', 'l', 'u', 's']},
#  '▁witnesses': {'freq': 5,
#   'swords': ['▁', 'w', 'i', 't', 'n', 'e', 's', 's', 'e', 's']},
#  '▁blessed': {'freq': 36, 'swords': ['▁', 'b', 'l', 'e', 's', 's', 'e', 'd']},
#  '▁mortal': {'freq': 55, 'swords': ['▁', 'm', 'o', 'r', 't', 'a', 'l']},
#  '▁fierceness': {'freq': 6,
#   'swords': ['▁', 'f', 'i', 'e', 'r', 'c', 'e', 'n', 'e', 's', 's']},
#  '▁need': {'freq': 36, 'swords': ['▁', 'n', 'e', 'e', 'd']},
#  '▁save': {'freq': 80, 'swords': ['▁', 's', 'a', 'v', 'e']},
#  '▁ruin': {'freq': 20, 'swords': ['▁', 'r', 'u', 'i', 'n']},
#  '▁seek': {'freq': 5, 'swords': ['▁', 's', 'e', 'e', 'k']},
#  '▁mad': {'freq': 21, 'swords': ['▁', 'm', 'a', 'd']},
#  '▁knows': {'freq': 30, 'swords': ['▁', 'k', 'n', 'o', 'w', 's']},
#  '▁after': {'freq': 288, 'swords': ['▁', 'a', 'f', 't', 'e', 'r']},
#  '▁dear': {'freq': 110, 'swords': ['▁', 'd', 'e', 'a', 'r']},
#  '▁comrade': {'freq': 75, 'swords': ['▁', 'c', 'o', 'm', 'r', 'a', 'd', 'e']},
#  '▁bidden': {'freq': 10, 'swords': ['▁', 'b', 'i', 'd', 'd', 'e', 'n']},
#  '▁woman': {'freq': 110, 'swords': ['▁', 'w', 'o', 'm', 'a', 'n']},
#  '▁loth': {'freq': 13, 'swords': ['▁', 'l', 'o', 't', 'h']},
#  '▁hoar': {'freq': 2, 'swords': ['▁', 'h', 'o', 'a', 'r']},
#  '▁weeping': {'freq': 68, 'swords': ['▁', 'w', 'e', 'e', 'p', 'i', 'n', 'g']},
#  '▁looking': {'freq': 86, 'swords': ['▁', 'l', 'o', 'o', 'k', 'i', 'n', 'g']},
#  '▁boundless': {'freq': 1,
#   'swords': ['▁', 'b', 'o', 'u', 'n', 'd', 'l', 'e', 's', 's']},
#  '▁waste': {'freq': 12, 'swords': ['▁', 'w', 'a', 's', 't', 'e']},
#  '▁waters': {'freq': 60, 'swords': ['▁', 'w', 'a', 't', 'e', 'r', 's']},
#  '▁raised': {'freq': 82, 'swords': ['▁', 'r', 'a', 'i', 's', 'e', 'd']},
#  '▁immortal': {'freq': 67,
#   'swords': ['▁', 'i', 'm', 'm', 'o', 'r', 't', 'a', 'l']},
#  '▁Mother': {'freq': 8, 'swords': ['▁', 'M', 'o', 't', 'h', 'e', 'r']},
#  '▁doomed': {'freq': 14, 'swords': ['▁', 'd', 'o', 'o', 'm', 'e', 'd']},
#  '▁little': {'freq': 80, 'swords': ['▁', 'l', 'i', 't', 't', 'l', 'e']},
#  '▁season': {'freq': 9, 'swords': ['▁', 's', 'e', 'a', 's', 'o', 'n']},
#  '▁thunders': {'freq': 4,
#   'swords': ['▁', 't', 'h', 'u', 'n', 'd', 'e', 'r', 's']},
#  '▁glorious': {'freq': 20,
#   'swords': ['▁', 'g', 'l', 'o', 'r', 'i', 'o', 'u', 's']},
#  '▁dishonour': {'freq': 8,
#   'swords': ['▁', 'd', 'i', 's', 'h', 'o', 'n', 'o', 'u', 'r']},
#  '▁robbed': {'freq': 19, 'swords': ['▁', 'r', 'o', 'b', 'b', 'e', 'd']},
#  '▁As': {'freq': 331, 'swords': ['▁', 'A', 's']},
#  '▁wept': {'freq': 43, 'swords': ['▁', 'w', 'e', 'p', 't']},
#  '▁aloud': {'freq': 42, 'swords': ['▁', 'a', 'l', 'o', 'u', 'd']},
#  '▁where': {'freq': 337, 'swords': ['▁', 'w', 'h', 'e', 'r', 'e']},
#  '▁depths': {'freq': 9, 'swords': ['▁', 'd', 'e', 'p', 't', 'h', 's']},
#  '▁hard': {'freq': 103, 'swords': ['▁', 'h', 'a', 'r', 'd']},
#  '▁Forthwith': {'freq': 18,
#   'swords': ['▁', 'F', 'o', 'r', 't', 'h', 'w', 'i', 't', 'h']},
#  '▁grey': {'freq': 27, 'swords': ['▁', 'g', 'r', 'e', 'y']},
#  '▁mist': {'freq': 13, 'swords': ['▁', 'm', 'i', 's', 't']},
#  '▁waves': {'freq': 49, 'swords': ['▁', 'w', 'a', 'v', 'e', 's']},
#  '▁caressed': {'freq': 6,
#   'swords': ['▁', 'c', 'a', 'r', 'e', 's', 's', 'e', 'd']},
#  '▁My': {'freq': 140, 'swords': ['▁', 'M', 'y']},
#  '▁grieves': {'freq': 4, 'swords': ['▁', 'g', 'r', 'i', 'e', 'v', 'e', 's']},
#  '▁Keep': {'freq': 6, 'swords': ['▁', 'K', 'e', 'e', 'p']},
#  '▁deep': {'freq': 59, 'swords': ['▁', 'd', 'e', 'e', 'p']},
#  '▁sigh': {'freq': 10, 'swords': ['▁', 's', 'i', 'g', 'h']},
#  '▁Thebe': {'freq': 4, 'swords': ['▁', 'T', 'h', 'e', 'b', 'e']},
#  '▁Eetion': {'freq': 11, 'swords': ['▁', 'E', 'e', 't', 'i', 'o', 'n']},
#  '▁sacked': {'freq': 32, 'swords': ['▁', 's', 'a', 'c', 'k', 'e', 'd']},
#  '▁spoil': {'freq': 16, 'swords': ['▁', 's', 'p', 'o', 'i', 'l']},
#  '▁shared': {'freq': 2, 'swords': ['▁', 's', 'h', 'a', 'r', 'e', 'd']},
#  '▁duly': {'freq': 6, 'swords': ['▁', 'd', 'u', 'l', 'y']},
#  '▁meed': {'freq': 3, 'swords': ['▁', 'm', 'e', 'e', 'd']},
#  '▁dearly': {'freq': 13, 'swords': ['▁', 'd', 'e', 'a', 'r', 'l', 'y']},
#  '▁deadly': {'freq': 16, 'swords': ['▁', 'd', 'e', 'a', 'd', 'l', 'y']},
#  '▁dart': {'freq': 12, 'swords': ['▁', 'd', 'a', 'r', 't']},
#  '▁died': {'freq': 27, 'swords': ['▁', 'd', 'i', 'e', 'd']},
#  '▁thick': {'freq': 89, 'swords': ['▁', 't', 'h', 'i', 'c', 'k']},
#  '▁everywhither': {'freq': 1,
#   'swords': ['▁', 'e', 'v', 'e', 'r', 'y', 'w', 'h', 'i', 't', 'h', 'e', 'r']},
#  '▁wide': {'freq': 29, 'swords': ['▁', 'w', 'i', 'd', 'e']},
#  '▁At': {'freq': 39, 'swords': ['▁', 'A', 't']},
#  '▁last': {'freq': 74, 'swords': ['▁', 'l', 'a', 's', 't']},
#  '▁fulness': {'freq': 1, 'swords': ['▁', 'f', 'u', 'l', 'n', 'e', 's', 's']},
#  '▁knowledge': {'freq': 10,
#   'swords': ['▁', 'k', 'n', 'o', 'w', 'l', 'e', 'd', 'g', 'e']},
#  '▁declared': {'freq': 5,
#   'swords': ['▁', 'd', 'e', 'c', 'l', 'a', 'r', 'e', 'd']},
#  '▁myself': {'freq': 146, 'swords': ['▁', 'm', 'y', 's', 'e', 'l', 'f']},
#  '▁Whereon': {'freq': 2, 'swords': ['▁', 'W', 'h', 'e', 'r', 'e', 'o', 'n']},
#  '▁threatened': {'freq': 6,
#   'swords': ['▁', 't', 'h', 'r', 'e', 'a', 't', 'e', 'n', 'e', 'd']},
#  '▁sending': {'freq': 11, 'swords': ['▁', 's', 'e', 'n', 'd', 'i', 'n', 'g']},
#  '▁just': {'freq': 107, 'swords': ['▁', 'j', 'u', 's', 't']},
#  '▁taken': {'freq': 106, 'swords': ['▁', 't', 'a', 'k', 'e', 'n']},
#  '▁Briseus': {'freq': 3, 'swords': ['▁', 'B', 'r', 'i', 's', 'e', 'u', 's']},
#  '▁Help': {'freq': 6, 'swords': ['▁', 'H', 'e', 'l', 'p']},
#  '▁able': {'freq': 46, 'swords': ['▁', 'a', 'b', 'l', 'e']},
#  '▁service': {'freq': 17, 'swords': ['▁', 's', 'e', 'r', 'v', 'i', 'c', 'e']},
#  '▁aid': {'freq': 9, 'swords': ['▁', 'a', 'i', 'd']},
#  '▁Ofttimes': {'freq': 1,
#   'swords': ['▁', 'O', 'f', 't', 't', 'i', 'm', 'e', 's']},
#  '▁glory': {'freq': 59, 'swords': ['▁', 'g', 'l', 'o', 'r', 'y']},
#  '▁saved': {'freq': 34, 'swords': ['▁', 's', 'a', 'v', 'e', 'd']},
#  '▁Saturn': {'freq': 92, 'swords': ['▁', 'S', 'a', 't', 'u', 'r', 'n']},
#  '▁Neptune': {'freq': 120, 'swords': ['▁', 'N', 'e', 'p', 't', 'u', 'n', 'e']},
#  '▁Pallas': {'freq': 22, 'swords': ['▁', 'P', 'a', 'l', 'l', 'a', 's']},
#  '▁bonds': {'freq': 5, 'swords': ['▁', 'b', 'o', 'n', 'd', 's']},
#  '▁delivered': {'freq': 9,
#   'swords': ['▁', 'd', 'e', 'l', 'i', 'v', 'e', 'r', 'e', 'd']},
#  '▁calling': {'freq': 16, 'swords': ['▁', 'c', 'a', 'l', 'l', 'i', 'n', 'g']},
#  '▁hundred': {'freq': 24, 'swords': ['▁', 'h', 'u', 'n', 'd', 'r', 'e', 'd']},
#  '▁handed': {'freq': 37, 'swords': ['▁', 'h', 'a', 'n', 'd', 'e', 'd']},
#  '▁monster': {'freq': 18, 'swords': ['▁', 'm', 'o', 'n', 's', 't', 'e', 'r']},
#  '▁call': {'freq': 51, 'swords': ['▁', 'c', 'a', 'l', 'l']},
#  '▁Briareus': {'freq': 1,
#   'swords': ['▁', 'B', 'r', 'i', 'a', 'r', 'e', 'u', 's']},
#  '▁Aegaeon': {'freq': 1, 'swords': ['▁', 'A', 'e', 'g', 'a', 'e', 'o', 'n']},
#  '▁beside': {'freq': 48, 'swords': ['▁', 'b', 'e', 's', 'i', 'd', 'e']},
#  '▁afraid': {'freq': 47, 'swords': ['▁', 'a', 'f', 'r', 'a', 'i', 'd']},
#  '▁bind': {'freq': 12, 'swords': ['▁', 'b', 'i', 'n', 'd']},
#  '▁remind': {'freq': 4, 'swords': ['▁', 'r', 'e', 'm', 'i', 'n', 'd']},
#  '▁clasp': {'freq': 4, 'swords': ['▁', 'c', 'l', 'a', 's', 'p']},
#  '▁knees': {'freq': 66, 'swords': ['▁', 'k', 'n', 'e', 'e', 's']},
#  '▁succour': {'freq': 3, 'swords': ['▁', 's', 'u', 'c', 'c', 'o', 'u', 'r']},
#  '▁hemmed': {'freq': 9, 'swords': ['▁', 'h', 'e', 'm', 'm', 'e', 'd']},
#  '▁sterns': {'freq': 9, 'swords': ['▁', 's', 't', 'e', 'r', 'n', 's']},
#  '▁perish': {'freq': 32, 'swords': ['▁', 'p', 'e', 'r', 'i', 's', 'h']},
#  '▁reap': {'freq': 5, 'swords': ['▁', 'r', 'e', 'a', 'p']},
#  '▁joy': {'freq': 17, 'swords': ['▁', 'j', 'o', 'y']},
#  '▁blindness': {'freq': 1,
#   'swords': ['▁', 'b', 'l', 'i', 'n', 'd', 'n', 'e', 's', 's']},
#  '▁offering': {'freq': 41,
#   'swords': ['▁', 'o', 'f', 'f', 'e', 'r', 'i', 'n', 'g']},
#  '▁Thetis': {'freq': 47, 'swords': ['▁', 'T', 'h', 'e', 't', 'i', 's']},
#  '▁woe': {'freq': 15, 'swords': ['▁', 'w', 'o', 'e']},
#  '▁suckled': {'freq': 4, 'swords': ['▁', 's', 'u', 'c', 'k', 'l', 'e', 'd']},
#  '▁Would': {'freq': 30, 'swords': ['▁', 'W', 'o', 'u', 'l', 'd']},
#  '▁indeed': {'freq': 107, 'swords': ['▁', 'i', 'n', 'd', 'e', 'e', 'd']},
#  '▁lived': {'freq': 38, 'swords': ['▁', 'l', 'i', 'v', 'e', 'd']},
#  '▁span': {'freq': 1, 'swords': ['▁', 's', 'p', 'a', 'n']},
#  '▁brief': {'freq': 3, 'swords': ['▁', 'b', 'r', 'i', 'e', 'f']},
#  '▁alas': {'freq': 4, 'swords': ['▁', 'a', 'l', 'a', 's']},
#  '▁short': {'freq': 20, 'swords': ['▁', 's', 'h', 'o', 'r', 't']},
#  '▁peers': {'freq': 7, 'swords': ['▁', 'p', 'e', 'e', 'r', 's']},
#  '▁nevertheless': {'freq': 49,
#   'swords': ['▁', 'n', 'e', 'v', 'e', 'r', 't', 'h', 'e', 'l', 'e', 's', 's']},
#  '▁snowy': {'freq': 7, 'swords': ['▁', 's', 'n', 'o', 'w', 'y']},
#  '▁heights': {'freq': 7, 'swords': ['▁', 'h', 'e', 'i', 'g', 'h', 't', 's']},
#  '▁tale': {'freq': 20, 'swords': ['▁', 't', 'a', 'l', 'e']},
#  '▁meanwhile': {'freq': 12,
#   'swords': ['▁', 'm', 'e', 'a', 'n', 'w', 'h', 'i', 'l', 'e']},
#  '▁hold': {'freq': 171, 'swords': ['▁', 'h', 'o', 'l', 'd']},
#  '▁aloof': {'freq': 22, 'swords': ['▁', 'a', 'l', 'o', 'o', 'f']},
#  '▁yesterday': {'freq': 11,
#   'swords': ['▁', 'y', 'e', 's', 't', 'e', 'r', 'd', 'a', 'y']},
#  '▁Oceanus': {'freq': 37, 'swords': ['▁', 'O', 'c', 'e', 'a', 'n', 'u', 's']},
#  '▁feast': {'freq': 30, 'swords': ['▁', 'f', 'e', 'a', 's', 't']},
#  '▁Ethiopians': {'freq': 5,
#   'swords': ['▁', 'E', 't', 'h', 'i', 'o', 'p', 'i', 'a', 'n', 's']},
#  '▁twelve': {'freq': 68, 'swords': ['▁', 't', 'w', 'e', 'l', 'v', 'e']},
#  '▁hence': {'freq': 10, 'swords': ['▁', 'h', 'e', 'n', 'c', 'e']},
#  '▁mansion': {'freq': 5, 'swords': ['▁', 'm', 'a', 'n', 's', 'i', 'o', 'n']},
#  '▁paved': {'freq': 3, 'swords': ['▁', 'p', 'a', 'v', 'e', 'd']},
#  '▁bronze': {'freq': 155, 'swords': ['▁', 'b', 'r', 'o', 'n', 'z', 'e']},
#  ...}

# %%
wp.words_wp['▁her']
# Out:
# {'freq': 1145, 'swords': ['▁', 'h', 'e', 'r']}

# %%
wp.vocab[:10]
# Out:
# ['Q', 'P', 'd', 'j', ')', 'U', 'Z', '[', 'q', 'm']

# %% [markdown]
# ## Quality of a Language Model

# %% [markdown]
# We compute the gain
# $$
# C(xy) \cdot (\log P(xy) - \log P(x) - \log P(y)).
# $$
# for all bigrams

# %%
class WordPiece():
    def __init__(self, merge_cnt=200):
        self.pattern = r'\p{P}|[^\s\p{P}]+'
        self.merge_cnt = merge_cnt

    def pretokenize(self, text):
        words = re.findall(self.pattern, text)
        words = list(map(lambda x: '▁' + x, words))
        return words

    def _wp_init(self, text):
        words = self.pretokenize(text)
        word_cnts = Counter(words)
        self.words_wp = {
            word: {'freq': freq, 'swords': list(word)}
            for word, freq in word_cnts.items()}
        self.vocab = list(
            set([char for word in self.words_wp
                 for char in self.words_wp[word]['swords']]))

    def _calc_pair_gains(self):
        sword_cnts = Counter()
        self.pair_gains = Counter()
        for word_dict in self.words_wp.values():
            subwords = tuple(word_dict['swords'])
            freq = word_dict['freq']
            for i in range(len(subwords) - 1):
                sword_cnts[subwords[i]] += freq
                self.pair_gains[subwords[i:i + 2]] += freq
            sword_cnts[subwords[len(subwords) - 1]] += freq
        pair_cnt = sum(self.pair_gains.values())
        sword_cnt = sum(sword_cnts.values())
        for pair in self.pair_gains:
            self.pair_gains[pair] *= (
                log(self.pair_gains[pair]/pair_cnt)
                - log(sword_cnts[pair[0]]/sword_cnt)
                - log(sword_cnts[pair[1]]/sword_cnt))

# %%
wp = WordPiece()
wp._wp_init(text)
wp._calc_pair_gains()

# %%
sorted(wp.pair_gains, key=wp.pair_gains.get, reverse=True)[:4]
# Out:
# [('t', 'h'), ('h', 'e'), ('a', 'n'), ('▁', 't')]

# %% [markdown]
# ## Constructing the Subwords
# We merge a pair in a sequence of subwords. The structure of the pair is a list as in: `['h', 'e']`. `swords` is also a list.

# %%
class WordPiece():
    def __init__(self, merge_cnt=200):
        self.pattern = r'\p{P}|[^\s\p{P}]+'
        self.merge_cnt = merge_cnt

    def pretokenize(self, text):
        words = re.findall(self.pattern, text)
        words = list(map(lambda x: '▁' + x, words))
        return words

    def _wp_init(self, text):
        words = self.pretokenize(text)
        word_cnts = Counter(words)
        self.words_wp = {
            word: {'freq': freq, 'swords': list(word)}
            for word, freq in word_cnts.items()}
        self.vocab = list(
            set([char for word in self.words_wp
                 for char in self.words_wp[word]['swords']]))

    def _calc_pair_gains(self):
        sword_cnts = Counter()
        self.pair_gains = Counter()
        for word_dict in self.words_wp.values():
            subwords = tuple(word_dict['swords'])
            freq = word_dict['freq']
            for i in range(len(subwords) - 1):
                sword_cnts[subwords[i]] += freq
                self.pair_gains[subwords[i:i + 2]] += freq
            sword_cnts[subwords[len(subwords) - 1]] += freq
        pair_cnt = sum(self.pair_gains.values())
        sword_cnt = sum(sword_cnts.values())
        for pair in self.pair_gains:
            self.pair_gains[pair] *= (
                log(self.pair_gains[pair]/pair_cnt)
                - log(sword_cnts[pair[0]]/sword_cnt)
                - log(sword_cnts[pair[1]]/sword_cnt))

    def _merge_pair(self, pair, swords):
        pair_str = ''.join(pair)
        i = 0
        temp = []
        while i < len(swords) - 1:
            if pair == swords[i:i + 2]:
                temp += [pair_str]
                i += 2
            else:
                temp += [swords[i]]
                i += 1
        if i == len(swords) - 1:
            temp += [swords[i]]
        swords = temp
        return swords

    def fit(self, text):
        self._wp_init(text)

        self.merge_ops = []
        for _ in range(self.merge_cnt):
            self._calc_pair_gains()
            self.best_pair = max(self.pair_gains,
                                 key=self.pair_gains.get)
            merge_op = list(self.best_pair)
            self.merge_ops.append(merge_op)
            for word_dict in self.words_wp.values():
                word_dict['swords'] = self._merge_pair(merge_op,
                                                       word_dict['swords'])

        self._build_vocab()

    def _build_vocab(self):
        swords = list(map(lambda x: ''.join(x), self.merge_ops))
        self.vocab += swords

# %%
wp = WordPiece()
wp.fit(text)

# %%
wp.merge_ops[:4]
# Out:
# [['t', 'h'], ['th', 'e'], ['a', 'n'], ['an', 'd']]

# %%
wp.vocab
# Out:
# ['Q',
#  'P',
#  'd',
#  'j',
#  ')',
#  'U',
#  'Z',
#  '[',
#  'q',
#  'm',
#  'p',
#  'l',
#  '-',
#  'W',
#  'A',
#  'E',
#  'M',
#  'y',
#  'X',
#  'w',
#  ']',
#  'T',
#  'L',
#  'B',
#  'i',
#  'b',
#  'I',
#  'O',
#  'v',
#  'k',
#  'Y',
#  ':',
#  "'",
#  'c',
#  's',
#  'x',
#  'N',
#  'R',
#  '?',
#  'g',
#  'S',
#  'h',
#  '&',
#  'K',
#  'a',
#  'e',
#  'o',
#  'D',
#  '!',
#  'r',
#  'V',
#  '.',
#  'n',
#  't',
#  '(',
#  '▁',
#  '"',
#  'u',
#  ',',
#  'G',
#  'C',
#  'z',
#  ';',
#  'H',
#  'J',
#  'f',
#  'F',
#  'th',
#  'the',
#  'an',
#  'and',
#  'in',
#  '▁the',
#  '▁,',
#  'ou',
#  '▁w',
#  '▁h',
#  'ing',
#  've',
#  '▁and',
#  '▁b',
#  'on',
#  'of',
#  '▁f',
#  '▁of',
#  '▁s',
#  '▁.',
#  '▁hi',
#  'to',
#  'll',
#  '▁to',
#  'you',
#  '▁he',
#  'en',
#  're',
#  '▁wh',
#  'ch',
#  '▁a',
#  '▁m',
#  '▁ha',
#  '▁wi',
#  '▁with',
#  '▁-',
#  '▁th',
#  '▁you',
#  '▁c',
#  'gh',
#  '▁sh',
#  'ow',
#  'or',
#  'om',
#  '▁him',
#  '▁for',
#  '▁his',
#  'us',
#  '▁g',
#  '▁I',
#  'Th',
#  '▁A',
#  '▁in',
#  '▁"',
#  'ed',
#  'at',
#  '▁that',
#  'ar',
#  '▁d',
#  '▁n',
#  'ther',
#  'le',
#  '▁no',
#  'ld',
#  'er',
#  '▁wa',
#  'ght',
#  '▁p',
#  '▁;',
#  '▁be',
#  'ly',
#  'es',
#  'is',
#  '▁was',
#  '▁go',
#  '▁will',
#  '▁l',
#  '▁Th',
#  'ould',
#  'id',
#  'it',
#  '▁on',
#  'ight',
#  '▁it',
#  '▁we',
#  'ver',
#  '▁have',
#  '▁had',
#  '▁bu',
#  'ay',
#  '▁but',
#  'ck',
#  'up',
#  '▁H',
#  '▁t',
#  '▁not',
#  '▁T',
#  '▁up',
#  '▁M',
#  '▁P',
#  '▁as',
#  '▁all',
#  'ill',
#  'ir',
#  'oun',
#  'un',
#  'out',
#  'ans',
#  '▁fr',
#  '▁from',
#  'ro',
#  'st',
#  'ent',
#  '▁st',
#  'se',
#  '▁sp',
#  '▁them',
#  'am',
#  'ad',
#  'ke',
#  '▁com',
#  'ound',
#  'ven',
#  'own',
#  'ce',
#  '▁Ach',
#  '▁their',
#  '▁Tro',
#  'ong',
#  '▁son',
#  'ough',
#  'our',
#  '▁were',
#  '▁Troj',
#  '▁they',
#  '▁my',
#  '▁me',
#  '▁man',
#  'ri',
#  '▁your',
#  'ain',
#  'Uly',
#  '▁who',
#  '▁He',
#  '▁is',
#  '▁this',
#  "▁'",
#  'ur',
#  '▁when',
#  '▁whi',
#  'tor',
#  'aid',
#  '▁by',
#  '▁hand',
#  'other',
#  'all',
#  '▁upon',
#  '▁said',
#  '▁so',
#  '▁her',
#  '▁Trojans',
#  'bout',
#  '▁li',
#  'ear',
#  '▁which',
#  '▁se',
#  '▁The',
#  '▁shi',
#  '▁ship',
#  '▁would',
#  '▁r',
#  '▁S',
#  'ore',
#  'ard',
#  'od',
#  'red',
#  'ind',
#  '▁god',
#  '▁about',
#  '▁W',
#  'sel',
#  '▁did',
#  '▁e',
#  '▁an',
#  'ome',
#  'ame',
#  'fore',
#  'self',
#  '▁she',
#  '▁should',
#  '▁shall',
#  '▁k',
#  '▁J',
#  '▁went',
#  'ove',
#  '▁Jove',
#  '▁into',
#  '▁now',
#  '▁br',
#  '▁str']

# %% [markdown]
# ## Vocabulary

# %%
wp.vocab.sort(key=lambda x: -len(x))

# %%
len(wp.vocab)
# Out:
# 267

# %%
wp.vocab[:10]
# Out:
# ['▁Trojans',
#  '▁should',
#  '▁their',
#  '▁which',
#  '▁would',
#  '▁about',
#  '▁shall',
#  '▁with',
#  '▁that',
#  '▁will']

# %% [markdown]
# ## Subword Tokenization

# %% [markdown]
# We write an encode function that breaks the words. We use a regex

# %%
class WordPiece():
    def __init__(self, merge_cnt=200):
        self.pattern = r'\p{P}|[^\s\p{P}]+'
        self.merge_cnt = merge_cnt

    def pretokenize(self, text):
        words = re.findall(self.pattern, text)
        words = list(map(lambda x: '▁' + x, words))
        return words

    def _wp_init(self, text):
        words = self.pretokenize(text)
        word_cnts = Counter(words)
        self.words_wp = {
            word: {'freq': freq, 'swords': list(word)}
            for word, freq in word_cnts.items()}
        self.vocab = list(
            set([char for word in self.words_wp
                 for char in self.words_wp[word]['swords']]))

    def _calc_pair_gains(self):
        sword_cnts = Counter()
        self.pair_gains = Counter()
        for word_dict in self.words_wp.values():
            subwords = tuple(word_dict['swords'])
            freq = word_dict['freq']
            for i in range(len(subwords) - 1):
                sword_cnts[subwords[i]] += freq
                self.pair_gains[subwords[i:i + 2]] += freq
            sword_cnts[subwords[len(subwords) - 1]] += freq
        pair_cnt = sum(self.pair_gains.values())
        sword_cnt = sum(sword_cnts.values())
        for pair in self.pair_gains:
            self.pair_gains[pair] *= (
                log(self.pair_gains[pair]/pair_cnt)
                - log(sword_cnts[pair[0]]/sword_cnt)
                - log(sword_cnts[pair[1]]/sword_cnt))

    def _merge_pair(self, pair, swords):
        pair_str = ''.join(pair)
        i = 0
        temp = []
        while i < len(swords) - 1:
            if pair == swords[i:i + 2]:
                temp += [pair_str]
                i += 2
            else:
                temp += [swords[i]]
                i += 1
        if i == len(swords) - 1:
            temp += [swords[i]]
        swords = temp
        return swords

    def fit(self, text):
        self._wp_init(text)

        self.merge_ops = []
        for _ in range(self.merge_cnt):
            self._calc_pair_gains()
            self.best_pair = max(self.pair_gains,
                                 key=self.pair_gains.get)
            merge_op = list(self.best_pair)
            self.merge_ops.append(merge_op)
            for word_dict in self.words_wp.values():
                word_dict['swords'] = self._merge_pair(merge_op,
                                                       word_dict['swords'])

        self._build_vocab()

    def _build_vocab(self):
        swords = list(map(lambda x: ''.join(x), self.merge_ops))
        self.vocab += swords
        self._create_regex()

    def _create_regex(self):
        self.vocab.sort(key=lambda x: -len(x))
        # We escape metachars as for '.'
        self.vocab = [re.escape(word) for word in self.vocab]
        self.sword_regex = '|'.join(self.vocab)

# %%
wp = WordPiece()
wp.fit(text)

# %%
wp.sword_regex
# Out:
# '▁Trojans|▁should|▁their|▁which|▁would|▁about|▁shall|▁with|▁that|▁will|▁have|▁from|▁them|▁were|▁Troj|▁they|▁your|▁this|▁when|▁hand|other|▁upon|▁said|▁ship|▁went|▁Jove|▁into|▁the|▁and|▁you|▁him|▁for|▁his|ther|▁was|ould|ight|▁had|▁but|▁not|▁all|▁com|ound|▁Ach|▁Tro|▁son|ough|▁man|▁who|▁whi|▁her|bout|▁The|▁shi|▁god|▁did|fore|self|▁she|▁now|▁str|the|and|ing|▁of|▁hi|▁to|you|▁he|▁wh|▁ha|▁wi|▁th|▁sh|▁in|▁no|▁wa|ght|▁be|▁go|▁Th|▁on|▁it|▁we|ver|▁bu|▁up|▁as|ill|oun|out|ans|▁fr|ent|▁st|▁sp|ven|own|ong|our|▁my|▁me|ain|Uly|▁He|▁is|tor|aid|▁by|all|▁so|▁li|ear|▁se|ore|ard|red|ind|sel|▁an|ome|ame|ove|▁br|th|an|in|▁,|ou|▁w|▁h|ve|▁b|on|of|▁f|▁s|▁\\.|to|ll|en|re|ch|▁a|▁m|▁\\-|▁c|gh|ow|or|om|us|▁g|▁I|Th|▁A|▁"|ed|at|ar|▁d|▁n|le|ld|er|▁p|▁;|ly|es|is|▁l|id|it|ay|ck|up|▁H|▁t|▁T|▁M|▁P|ir|un|ro|st|se|am|ad|ke|ce|ri|▁\'|ur|▁r|▁S|od|▁W|▁e|▁k|▁J|Q|P|d|j|\\)|U|Z|\\[|q|m|p|l|\\-|W|A|E|M|y|X|w|\\]|T|L|B|i|b|I|O|v|k|Y|:|\'|c|s|x|N|R|\\?|g|S|h|\\&|K|a|e|o|D|!|r|V|\\.|n|t|\\(|▁|"|u|,|G|C|z|;|H|J|f|F'

# %%
re.findall(wp.sword_regex, '▁Therefore')
# Out:
# ['▁The', 're', 'fore']

# %%
re.findall(wp.sword_regex, '▁touché')
# Out:
# ['▁to', 'u', 'ch']

# %%
class WordPiece():
    def __init__(self, merge_cnt=200):
        self.pattern = r'\p{P}|[^\s\p{P}]+'
        self.merge_cnt = merge_cnt
        self.unk_word = '[UNK]'

    def pretokenize(self, text):
        words = re.findall(self.pattern, text)
        words = list(map(lambda x: '▁' + x, words))
        return words

    def _wp_init(self, text):
        words = self.pretokenize(text)
        word_cnts = Counter(words)
        self.words_wp = {
            word: {'freq': freq, 'swords': list(word)}
            for word, freq in word_cnts.items()}
        self.vocab = list(
            set([char for word in self.words_wp
                 for char in self.words_wp[word]['swords']]))

    def _calc_pair_gains(self):
        sword_cnts = Counter()
        self.pair_gains = Counter()
        for word_dict in self.words_wp.values():
            subwords = tuple(word_dict['swords'])
            freq = word_dict['freq']
            for i in range(len(subwords) - 1):
                sword_cnts[subwords[i]] += freq
                self.pair_gains[subwords[i:i + 2]] += freq
            sword_cnts[subwords[len(subwords) - 1]] += freq
        pair_cnt = sum(self.pair_gains.values())
        sword_cnt = sum(sword_cnts.values())
        for pair in self.pair_gains:
            self.pair_gains[pair] *= (
                log(self.pair_gains[pair]/pair_cnt)
                - log(sword_cnts[pair[0]]/sword_cnt)
                - log(sword_cnts[pair[1]]/sword_cnt))

    def _merge_pair(self, pair, swords):
        pair_str = ''.join(pair)
        i = 0
        temp = []
        while i < len(swords) - 1:
            if pair == swords[i:i + 2]:
                temp += [pair_str]
                i += 2
            else:
                temp += [swords[i]]
                i += 1
        if i == len(swords) - 1:
            temp += [swords[i]]
        swords = temp
        return swords

    def fit(self, text):
        self._wp_init(text)

        self.merge_ops = []
        for _ in range(self.merge_cnt):
            self._calc_pair_gains()
            self.best_pair = max(self.pair_gains,
                                 key=self.pair_gains.get)
            merge_op = list(self.best_pair)
            self.merge_ops.append(merge_op)
            for word_dict in self.words_wp.values():
                word_dict['swords'] = self._merge_pair(merge_op,
                                                       word_dict['swords'])

        self._build_vocab()

    def _build_vocab(self):
        swords = list(map(lambda x: ''.join(x), self.merge_ops))
        self.vocab += swords
        self._create_regex()

    def _create_regex(self):
        self.vocab.sort(key=lambda x: -len(x))
        # We escape metachars as for '.'
        self.vocab = [re.escape(word) for word in self.vocab]
        self.sword_regex = '|'.join(self.vocab)

    def encode(self, word):
        subwords = re.findall(self.sword_regex, word)
        if ''.join(subwords) != word:
            # some subwords are not in the vocabulary
            subwords = [self.unk_word]
        return subwords

# %%
wp = WordPiece()
wp.fit(text)

# %%
wp.encode('▁Therefore')
# Out:
# ['▁The', 're', 'fore']

# %%
wp.encode('▁touché')
# Out:
# ['[UNK]']

# %% [markdown]
# We can finally write the complete subword tokenization function. We use a cache to speed up the search

# %%
class WordPiece():
    def __init__(self, merge_cnt=200):
        self.pattern = r'\p{P}|[^\s\p{P}]+'
        self.merge_cnt = merge_cnt
        self.unk_word = '[UNK]'

    def pretokenize(self, text):
        words = re.findall(self.pattern, text)
        words = list(map(lambda x: '▁' + x, words))
        return words

    def _wp_init(self, text):
        words = self.pretokenize(text)
        word_cnts = Counter(words)
        self.words_wp = {
            word: {'freq': freq, 'swords': list(word)}
            for word, freq in word_cnts.items()}
        self.vocab = list(
            set([char for word in self.words_wp
                 for char in self.words_wp[word]['swords']]))

    def _calc_pair_gains(self):
        sword_cnts = Counter()
        self.pair_gains = Counter()
        for word_dict in self.words_wp.values():
            subwords = tuple(word_dict['swords'])
            freq = word_dict['freq']
            for i in range(len(subwords) - 1):
                sword_cnts[subwords[i]] += freq
                self.pair_gains[subwords[i:i + 2]] += freq
            sword_cnts[subwords[len(subwords) - 1]] += freq
        pair_cnt = sum(self.pair_gains.values())
        sword_cnt = sum(sword_cnts.values())
        for pair in self.pair_gains:
            self.pair_gains[pair] *= (
                log(self.pair_gains[pair]/pair_cnt)
                - log(sword_cnts[pair[0]]/sword_cnt)
                - log(sword_cnts[pair[1]]/sword_cnt))

    def _merge_pair(self, pair, swords):
        pair_str = ''.join(pair)
        i = 0
        temp = []
        while i < len(swords) - 1:
            if pair == swords[i:i + 2]:
                temp += [pair_str]
                i += 2
            else:
                temp += [swords[i]]
                i += 1
        if i == len(swords) - 1:
            temp += [swords[i]]
        swords = temp
        return swords

    def fit(self, text):
        self._wp_init(text)

        self.merge_ops = []
        for _ in range(self.merge_cnt):
            self._calc_pair_gains()
            self.best_pair = max(self.pair_gains,
                                 key=self.pair_gains.get)
            merge_op = list(self.best_pair)
            self.merge_ops.append(merge_op)
            for word_dict in self.words_wp.values():
                word_dict['swords'] = self._merge_pair(merge_op,
                                                       word_dict['swords'])

        self._build_vocab()

    def _build_vocab(self):
        swords = list(map(lambda x: ''.join(x), self.merge_ops))
        self.vocab += swords
        self._create_regex()

    def _create_regex(self):
        self.vocab.sort(key=lambda x: -len(x))
        # We escape metachars as for '.'
        self.vocab = [re.escape(word) for word in self.vocab]
        self.sword_regex = '|'.join(self.vocab)

    def encode(self, word):
        subwords = re.findall(self.sword_regex, word)
        if ''.join(subwords) != word:
            # some subwords are not in the vocabulary
            subwords = [self.unk_word]
        return subwords

    def tokenize(self, text):
        tokenized_text = []
        cache = {}
        words = self.pretokenize(text)
        for word in words:
            if word not in cache:
                cache[word] = self.encode(word)
            subwords = cache[word]
            tokenized_text += subwords
        return tokenized_text

# %%
wp = WordPiece()
wp.fit(text)

# %%
wp.tokenize(text)
# Out:
# ['▁',
#  'B',
#  'O',
#  'O',
#  'K',
#  '▁I',
#  '▁S',
#  'ing',
#  '▁,',
#  '▁',
#  'O',
#  '▁god',
#  'd',
#  'es',
#  's',
#  '▁,',
#  '▁the',
#  '▁an',
#  'g',
#  'er',
#  '▁of',
#  '▁Ach',
#  'ill',
#  'es',
#  '▁son',
#  '▁of',
#  '▁P',
#  'e',
#  'le',
#  'us',
#  '▁,',
#  '▁that',
#  '▁br',
#  'ough',
#  't',
#  '▁c',
#  'oun',
#  't',
#  'le',
#  's',
#  's',
#  '▁',
#  'ill',
#  's',
#  '▁upon',
#  '▁the',
#  '▁Ach',
#  'a',
#  'e',
#  'ans',
#  '▁.',
#  '▁M',
#  'an',
#  'y',
#  '▁a',
#  '▁br',
#  'a',
#  've',
#  '▁so',
#  'u',
#  'l',
#  '▁did',
#  '▁it',
#  '▁se',
#  'n',
#  'd',
#  '▁h',
#  'ur',
#  'r',
#  'y',
#  'ing',
#  '▁d',
#  'own',
#  '▁to',
#  '▁H',
#  'ad',
#  'es',
#  '▁,',
#  '▁and',
#  '▁man',
#  'y',
#  '▁a',
#  '▁her',
#  'o',
#  '▁did',
#  '▁it',
#  '▁',
#  'y',
#  'i',
#  'e',
#  'ld',
#  '▁a',
#  '▁p',
#  're',
#  'y',
#  '▁to',
#  '▁d',
#  'o',
#  'g',
#  's',
#  '▁and',
#  '▁',
#  'v',
#  'u',
#  'l',
#  't',
#  'ur',
#  'es',
#  '▁,',
#  '▁for',
#  '▁so',
#  '▁were',
#  '▁the',
#  '▁c',
#  'oun',
#  'sel',
#  's',
#  '▁of',
#  '▁Jove',
#  '▁f',
#  'u',
#  'l',
#  'f',
#  'ill',
#  'ed',
#  '▁from',
#  '▁the',
#  '▁d',
#  'ay',
#  '▁on',
#  '▁which',
#  '▁the',
#  '▁son',
#  '▁of',
#  '▁A',
#  't',
#  're',
#  'us',
#  '▁,',
#  '▁k',
#  'ing',
#  '▁of',
#  '▁me',
#  'n',
#  '▁,',
#  '▁and',
#  '▁g',
#  're',
#  'at',
#  '▁Ach',
#  'ill',
#  'es',
#  '▁,',
#  '▁f',
#  'ir',
#  'st',
#  '▁f',
#  'e',
#  'll',
#  '▁',
#  'out',
#  '▁with',
#  '▁on',
#  'e',
#  '▁an',
#  'other',
#  '▁.',
#  '▁A',
#  'n',
#  'd',
#  '▁which',
#  '▁of',
#  '▁the',
#  '▁god',
#  's',
#  '▁was',
#  '▁it',
#  '▁that',
#  '▁se',
#  't',
#  '▁them',
#  '▁on',
#  '▁to',
#  '▁',
#  'q',
#  'u',
#  'ar',
#  're',
#  'l',
#  '▁',
#  '?',
#  '▁I',
#  't',
#  '▁was',
#  '▁the',
#  '▁son',
#  '▁of',
#  '▁Jove',
#  '▁and',
#  '▁',
#  'L',
#  'e',
#  'to',
#  '▁;',
#  '▁for',
#  '▁he',
#  '▁was',
#  '▁an',
#  'g',
#  'r',
#  'y',
#  '▁with',
#  '▁the',
#  '▁k',
#  'ing',
#  '▁and',
#  '▁se',
#  'n',
#  't',
#  '▁a',
#  '▁p',
#  'es',
#  't',
#  'i',
#  'le',
#  'n',
#  'ce',
#  '▁upon',
#  '▁the',
#  '▁h',
#  'o',
#  'st',
#  '▁to',
#  '▁p',
#  'l',
#  'a',
#  'g',
#  'u',
#  'e',
#  '▁the',
#  '▁p',
#  'e',
#  'o',
#  'p',
#  'le',
#  '▁,',
#  '▁be',
#  'c',
#  'a',
#  'us',
#  'e',
#  '▁the',
#  '▁son',
#  '▁of',
#  '▁A',
#  't',
#  're',
#  'us',
#  '▁had',
#  '▁d',
#  'is',
#  'h',
#  'on',
#  'our',
#  'ed',
#  '▁',
#  'C',
#  'h',
#  'r',
#  'y',
#  'se',
#  's',
#  '▁his',
#  '▁p',
#  'ri',
#  'es',
#  't',
#  '▁.',
#  '▁',
#  'N',
#  'ow',
#  '▁',
#  'C',
#  'h',
#  'r',
#  'y',
#  'se',
#  's',
#  '▁had',
#  '▁com',
#  'e',
#  '▁to',
#  '▁the',
#  '▁ship',
#  's',
#  '▁of',
#  '▁the',
#  '▁Ach',
#  'a',
#  'e',
#  'ans',
#  '▁to',
#  '▁fr',
#  'e',
#  'e',
#  '▁his',
#  '▁d',
#  'a',
#  'u',
#  'ght',
#  'er',
#  '▁,',
#  '▁and',
#  '▁had',
#  '▁br',
#  'ough',
#  't',
#  '▁with',
#  '▁him',
#  '▁a',
#  '▁g',
#  're',
#  'at',
#  '▁r',
#  'ans',
#  'om',
#  '▁',
#  ':',
#  '▁m',
#  'ore',
#  'ove',
#  'r',
#  '▁he',
#  '▁b',
#  'ore',
#  '▁in',
#  '▁his',
#  '▁hand',
#  '▁the',
#  '▁s',
#  'ce',
#  'p',
#  't',
#  're',
#  '▁of',
#  '▁A',
#  'p',
#  'o',
#  'll',
#  'o',
#  '▁w',
#  're',
#  'at',
#  'h',
#  'ed',
#  '▁with',
#  '▁a',
#  '▁s',
#  'up',
#  'p',
#  'l',
#  'i',
#  'an',
#  't',
#  "▁'",
#  '▁s',
#  '▁w',
#  're',
#  'at',
#  'h',
#  '▁and',
#  '▁he',
#  '▁be',
#  's',
#  'ough',
#  't',
#  '▁the',
#  '▁Ach',
#  'a',
#  'e',
#  'ans',
#  '▁,',
#  '▁but',
#  '▁m',
#  'o',
#  'st',
#  '▁of',
#  '▁all',
#  '▁the',
#  '▁t',
#  'w',
#  'o',
#  '▁son',
#  's',
#  '▁of',
#  '▁A',
#  't',
#  're',
#  'us',
#  '▁,',
#  '▁who',
#  '▁were',
#  '▁their',
#  '▁c',
#  'h',
#  'i',
#  'e',
#  'f',
#  's',
#  '▁.',
#  '▁"',
#  '▁S',
#  'on',
#  's',
#  '▁of',
#  '▁A',
#  't',
#  're',
#  'us',
#  '▁,',
#  '▁"',
#  '▁he',
#  '▁c',
#  'ri',
#  'ed',
#  '▁,',
#  '▁"',
#  '▁and',
#  '▁all',
#  '▁',
#  'other',
#  '▁Ach',
#  'a',
#  'e',
#  'ans',
#  '▁,',
#  '▁m',
#  'ay',
#  '▁the',
#  '▁god',
#  's',
#  '▁who',
#  '▁d',
#  'w',
#  'e',
#  'll',
#  '▁in',
#  '▁',
#  'O',
#  'ly',
#  'm',
#  'p',
#  'us',
#  '▁g',
#  'r',
#  'an',
#  't',
#  '▁you',
#  '▁to',
#  '▁s',
#  'a',
#  'ck',
#  '▁the',
#  '▁c',
#  'it',
#  'y',
#  '▁of',
#  '▁P',
#  'ri',
#  'am',
#  '▁,',
#  '▁and',
#  '▁to',
#  '▁r',
#  'e',
#  'a',
#  'ch',
#  '▁your',
#  '▁h',
#  'ome',
#  's',
#  '▁in',
#  '▁s',
#  'a',
#  'f',
#  'e',
#  't',
#  'y',
#  '▁;',
#  '▁but',
#  '▁fr',
#  'e',
#  'e',
#  '▁my',
#  '▁d',
#  'a',
#  'u',
#  'ght',
#  'er',
#  '▁,',
#  '▁and',
#  '▁a',
#  'c',
#  'ce',
#  'p',
#  't',
#  '▁a',
#  '▁r',
#  'ans',
#  'om',
#  '▁for',
#  '▁her',
#  '▁,',
#  '▁in',
#  '▁r',
#  'e',
#  'ver',
#  'en',
#  'ce',
#  '▁to',
#  '▁A',
#  'p',
#  'o',
#  'll',
#  'o',
#  '▁,',
#  '▁son',
#  '▁of',
#  '▁Jove',
#  '▁.',
#  '▁"',
#  '▁',
#  'O',
#  'n',
#  '▁this',
#  '▁the',
#  '▁r',
#  'es',
#  't',
#  '▁of',
#  '▁the',
#  '▁Ach',
#  'a',
#  'e',
#  'ans',
#  '▁with',
#  '▁on',
#  'e',
#  '▁',
#  'v',
#  'o',
#  'i',
#  'ce',
#  '▁were',
#  '▁for',
#  '▁r',
#  'es',
#  'p',
#  'e',
#  'c',
#  't',
#  'ing',
#  '▁the',
#  '▁p',
#  'ri',
#  'es',
#  't',
#  '▁and',
#  '▁t',
#  'a',
#  'k',
#  'ing',
#  '▁the',
#  '▁r',
#  'ans',
#  'om',
#  '▁that',
#  '▁he',
#  '▁of',
#  'f',
#  'er',
#  'ed',
#  '▁;',
#  '▁but',
#  '▁not',
#  '▁so',
#  '▁A',
#  'g',
#  'ame',
#  'm',
#  'n',
#  'on',
#  '▁,',
#  '▁who',
#  '▁sp',
#  'o',
#  'ke',
#  '▁f',
#  'i',
#  'er',
#  'ce',
#  'ly',
#  '▁to',
#  '▁him',
#  '▁and',
#  '▁se',
#  'n',
#  't',
#  '▁him',
#  '▁r',
#  'ough',
#  'ly',
#  '▁a',
#  'w',
#  'ay',
#  '▁.',
#  '▁"',
#  '▁',
#  'O',
#  'ld',
#  '▁man',
#  '▁,',
#  '▁"',
#  '▁said',
#  '▁he',
#  '▁,',
#  '▁"',
#  '▁l',
#  'e',
#  't',
#  '▁me',
#  '▁not',
#  '▁f',
#  'ind',
#  '▁you',
#  '▁t',
#  'ar',
#  'r',
#  'y',
#  'ing',
#  '▁about',
#  '▁',
#  'our',
#  '▁ship',
#  's',
#  '▁,',
#  '▁no',
#  'r',
#  '▁',
#  'y',
#  'e',
#  't',
#  '▁com',
#  'ing',
#  '▁her',
#  'e',
#  'a',
#  'f',
#  't',
#  'er',
#  '▁.',
#  '▁',
#  'Y',
#  'our',
#  '▁s',
#  'ce',
#  'p',
#  't',
#  're',
#  '▁of',
#  '▁the',
#  '▁god',
#  '▁and',
#  '▁your',
#  '▁w',
#  're',
#  'at',
#  'h',
#  '▁shall',
#  '▁p',
#  'ro',
#  'f',
#  'it',
#  '▁you',
#  '▁not',
#  'h',
#  'ing',
#  '▁.',
#  '▁I',
#  '▁will',
#  '▁not',
#  '▁fr',
#  'e',
#  'e',
#  '▁her',
#  '▁.',
#  '▁S',
#  'h',
#  'e',
#  '▁shall',
#  '▁g',
#  'ro',
#  'w',
#  '▁',
#  'o',
#  'ld',
#  '▁in',
#  '▁my',
#  '▁h',
#  'ou',
#  'se',
#  '▁a',
#  't',
#  '▁A',
#  'r',
#  'g',
#  'o',
#  's',
#  '▁f',
#  'ar',
#  '▁from',
#  '▁her',
#  '▁',
#  'own',
#  '▁h',
#  'ome',
#  '▁,',
#  '▁bu',
#  's',
#  'y',
#  'ing',
#  '▁her',
#  'self',
#  '▁with',
#  '▁her',
#  '▁l',
#  'o',
#  'om',
#  '▁and',
#  '▁',
#  'v',
#  'is',
#  'it',
#  'ing',
#  '▁my',
#  '▁c',
#  'ou',
#  'ch',
#  '▁;',
#  '▁so',
#  '▁go',
#  '▁,',
#  '▁and',
#  '▁d',
#  'o',
#  '▁not',
#  '▁p',
#  'ro',
#  'v',
#  'o',
#  'ke',
#  '▁me',
#  '▁',
#  'or',
#  '▁it',
#  '▁shall',
#  '▁be',
#  '▁the',
#  '▁w',
#  'or',
#  'se',
#  '▁for',
#  '▁you',
#  '▁.',
#  '▁"',
#  '▁The',
#  '▁',
#  'o',
#  'ld',
#  '▁man',
#  '▁f',
#  'ear',
#  'ed',
#  '▁him',
#  '▁and',
#  '▁',
#  'o',
#  'b',
#  'e',
#  'y',
#  'ed',
#  '▁.',
#  '▁',
#  'N',
#  'o',
#  't',
#  '▁a',
#  '▁w',
#  'or',
#  'd',
#  '▁he',
#  '▁sp',
#  'o',
#  'ke',
#  '▁,',
#  '▁but',
#  '▁went',
#  '▁by',
#  '▁the',
#  '▁sh',
#  'ore',
#  '▁of',
#  '▁the',
#  '▁so',
#  'un',
#  'd',
#  'ing',
#  '▁se',
#  'a',
#  '▁and',
#  '▁p',
#  'r',
#  'ay',
#  'ed',
#  '▁a',
#  'p',
#  'ar',
#  't',
#  '▁to',
#  '▁',
#  'K',
#  'ing',
#  '▁A',
#  'p',
#  'o',
#  'll',
#  'o',
#  '▁who',
#  'm',
#  '▁l',
#  'ove',
#  'ly',
#  '▁',
#  'L',
#  'e',
#  'to',
#  '▁had',
#  '▁b',
#  'or',
#  'n',
#  'e',
#  '▁.',
#  '▁"',
#  '▁He',
#  'ar',
#  '▁me',
#  '▁,',
#  '▁"',
#  '▁he',
#  '▁c',
#  'ri',
#  'ed',
#  '▁,',
#  '▁"',
#  '▁',
#  'O',
#  '▁god',
#  '▁of',
#  '▁the',
#  '▁s',
#  'i',
#  'l',
#  'ver',
#  '▁b',
#  'ow',
#  '▁,',
#  '▁that',
#  '▁p',
#  'ro',
#  't',
#  'e',
#  'c',
#  't',
#  'es',
#  't',
#  '▁',
#  'C',
#  'h',
#  'r',
#  'y',
#  'se',
#  '▁and',
#  '▁h',
#  'o',
#  'ly',
#  '▁',
#  'C',
#  'ill',
#  'a',
#  '▁and',
#  '▁r',
#  'u',
#  'le',
#  'st',
#  '▁T',
#  'en',
#  'ed',
#  'o',
#  's',
#  '▁with',
#  '▁th',
#  'y',
#  '▁m',
#  'ight',
#  '▁,',
#  '▁he',
#  'ar',
#  '▁me',
#  '▁',
#  'o',
#  'h',
#  '▁th',
#  'ou',
#  '▁of',
#  '▁S',
#  'm',
#  'in',
#  'the',
#  '▁.',
#  '▁I',
#  'f',
#  '▁I',
#  '▁have',
#  '▁e',
#  'ver',
#  '▁d',
#  'e',
#  'ck',
#  'ed',
#  '▁your',
#  '▁t',
#  'e',
#  'm',
#  'p',
#  'le',
#  '▁with',
#  '▁g',
#  'ar',
#  'l',
#  'and',
#  's',
#  '▁,',
#  '▁',
#  'or',
#  '▁bu',
#  'r',
#  'n',
#  'ed',
#  '▁your',
#  '▁th',
#  'i',
#  'gh',
#  '▁-',
#  '▁b',
#  'on',
#  'es',
#  '▁in',
#  '▁f',
#  'at',
#  '▁of',
#  '▁bu',
#  'll',
#  's',
#  '▁',
#  'or',
#  '▁go',
#  'at',
#  's',
#  '▁,',
#  '▁g',
#  'r',
#  'an',
#  't',
#  '▁my',
#  '▁p',
#  'r',
#  'ay',
#  'er',
#  '▁,',
#  '▁and',
#  '▁l',
#  'e',
#  't',
#  '▁your',
#  '▁a',
#  'r',
#  'ro',
#  'w',
#  's',
#  '▁a',
#  ...]

# %%
swords = wp.tokenize('Sit careless in the shade!')
swords
# Out:
# ['▁S',
#  'it',
#  '▁c',
#  'ar',
#  'e',
#  'le',
#  's',
#  's',
#  '▁in',
#  '▁the',
#  '▁sh',
#  'ad',
#  'e',
#  '▁',
#  '!']

# %% [markdown]
# ## BERT's WordPiece

# %%
def bert_wp(swords):
    i = 0
    while i < len(swords) - 1:
        if swords[i] == '▁':
            swords = swords[:i] + \
                [''.join([swords[i], swords[i + 1]])] + swords[i + 2:]
        i += 1
    return [sword[1:] if sword[0] == '▁' else '##' + sword
            for sword in swords]

# %%
bert_wp(swords)
# Out:
# ['S',
#  '##it',
#  'c',
#  '##ar',
#  '##e',
#  '##le',
#  '##s',
#  '##s',
#  'in',
#  'the',
#  'sh',
#  '##ad',
#  '##e',
#  '!']
